# %%
import re
import numpy as np

# %%
def load_steps(fname='day22_cubes.txt'):
    with open(fname) as infile:
        data_raw = [l.strip() for l in infile]

    pattern = r'(\w+) x=(.*)\.\.(.*),y=(.*)\.\.(.*),z=(.*)\.\.(.*)'
    steps = []
    for line in data_raw:
        state, xmin, xmax, ymin, ymax, zmin, zmax = re.match(pattern, line).groups()
        state = 1 if state == 'on' else 0
        steps.append((state, (int(xmin), int(xmax)+1),
                      (int(ymin), int(ymax)+1), (int(zmin), int(zmax)+1)))
    return steps

# %%
steps = load_steps()

# %%
steps[:25]
# Out:
# [(1, (0, 45), (-37, 13), (-13, 32)),
#  (1, (-35, 20), (-9, 38), (-14, 40)),
#  (1, (-34, 21), (-25, 26), (-38, 8)),
#  (1, (-29, 20), (-43, 10), (-18, 33)),
#  (1, (-34, 21), (-3, 48), (-45, 7)),
#  (1, (-46, 3), (-25, 26), (-1, 48)),
#  (1, (-41, 5), (-15, 30), (-14, 37)),
#  (1, (-49, 3), (-16, 36), (-15, 34)),
#  (1, (-45, 0), (-9, 46), (-12, 38)),
#  (1, (-49, -3), (-44, 8), (-41, 12)),
#  (0, (-45, -30), (-9, 4), (-30, -15)),
#  (1, (-38, 15), (-39, 9), (-42, 11)),
#  (0, (-19, -2), (-21, -11), (5, 24)),
#  (1, (-35, 14), (-34, 17), (-25, 30)),
#  (0, (-46, -27), (-46, -35), (-42, -30)),
#  (1, (-19, 29), (-47, 0), (-35, 13)),
#  (0, (19, 32), (-22, -6), (-30, -10)),
#  (1, (-13, 37), (-9, 42), (-12, 37)),
#  (0, (-31, -19), (-41, -31), (-38, -25)),
#  (1, (-31, 15), (-37, 10), (-45, 5)),
#  (1, (-73938, -62195), (3443, 9035), (-32612, -17020)),
#  (1, (11497, 31461), (60006, 90797), (-22240, 13122)),
#  (1, (-84785, -70988), (-24232, 2944), (1355, 33301)),
#  (1, (-62304, -41673), (20801, 37686), (-72029, -48577)),
#  (1, (27091, 35478), (65585, 68641), (27496, 41808))]

# %% [markdown]
# # Part 1

# %%
steps = load_steps()
#steps = load_steps('day22_example.txt')
#steps=[(1, (10, 10), (10, 10), (10, 10))]

# %%
region = np.zeros((101, 101, 101))
zero = (50, 50, 50)
step_counters = []

for state, xrange, yrange, zrange in steps:
    xi, xf = xrange[0] + zero[0], xrange[1] + zero[0]
    yi, yf = yrange[0] + zero[1], yrange[1] + zero[1]
    zi, zf = zrange[0] + zero[2], zrange[1] + zero[2]
    if (0<= xi <= region.shape[0] and 0<= xf <= region.shape[0] and
        0<= yi <= region.shape[1] and 0<= yf <= region.shape[1] and
        0<= zi <= region.shape[2] and 0<= zf <= region.shape[2]):
        print(xi, xf, yi, yf, zi, zf)
        region[xi:xf, yi:yf, zi:zf] = state
    step_counters.append(region.sum())
# Out:
# 50 95 13 63 37 82
# 15 70 41 88 36 90
# 16 71 25 76 12 58
# 21 70 7 60 32 83
# 16 71 47 98 5 57
# 4 53 25 76 49 98
# 9 55 35 80 36 87
# 1 53 34 86 35 84
# 5 50 41 96 38 88
# 1 47 6 58 9 62
# 5 20 41 54 20 35
# 12 65 11 59 8 61
# 31 48 29 39 55 74
# 15 64 16 67 25 80
# 4 23 4 15 8 20
# 31 79 3 50 15 63
# 69 82 28 44 20 40
# 37 87 41 92 38 87
# 19 31 9 19 12 25
# 19 65 13 60 5 55

# %%
int(region.sum())
# Out:
# 596989

# %% [markdown]
# # Part 2

# %%
arr = np.array([(xlo, xhi, ylo, yhi, zlo, zhi)
                for _, (xlo, xhi), (ylo, yhi), (zlo, zhi) in steps])
print(np.min(arr, axis=0)[::2])
print(np.max(arr, axis=0)[1::2])
# Out:
# [-97641 -98161 -93592]
# [97741 94724 98699]

# %% [markdown]
# ### Not enough memory for previous approach

# %% [markdown]
# ### We gotta keep track of the abstract cuboids
# - Easy to figure out sizes of cuboids
# - Tricky to figure out the overlaps
# - Then applying all overlaps in correct order
#
# How to do it
# - Keep a number of active cubes
# - Keep a list of cuboid regions that are on
# - Whenever adding a new one that's on, check for overlap with existing on-regions
#     - If there's overlap, subtract volume from the counter
# - Then check for overlap with tracked off-regions (only part of on-cuboids)
#     - If there's overlap, add new cuboid that's on
#         - Add its volume to the counter
# - When adding a new one that's off, check for overlap with all existing on-regions
#     - If there's no overlap, ignore it (unlikely)
#     - If there's overlap, create a new cuboid to track it (state = off)
#         - Attach those to the mother on-cuboid
#         - ~~Order is important~~
#     - Check all newly created cuboids for overlaps
#         - Subtract (volume of created cuboids - volume of their overlaps) from counter

# %%
class Cuboid():
    def __init__(self, xrange, yrange, zrange):
        self.xlo, self.xhi = xrange
        self.ylo, self.yhi = yrange
        self.zlo, self.zhi = zrange
        self.offs = []
    
    def __eq__(self, other):
        eq = (self.xlo == other.xlo and
              self.xhi == other.xhi and
              self.ylo == other.ylo and
              self.yhi == other.yhi and
              self.zlo == other.zlo and
              self.zhi == other.zhi)
        return eq
    
    @property
    def ranges(self):
        return ((self.xlo, self.xhi), (self.ylo, self.yhi),
                (self.zlo, self.zhi))
    
    @property
    def volume(self):
        v = ((self.xhi - self.xlo) *
             (self.yhi - self.ylo) *
             (self.zhi - self.zlo))
        assert v > 0
        return v
    
    @property
    def vertices(self):
        vertices = [(x,y,x)
                    for x in (self.xlo, self.xhi)
                    for y in (self.ylo, self.yhi)
                    for z in (self.zlo, self.zhi)]
        return vertices
    
    def overlap(self, other):
        xlo = max(self.xlo, other.xlo)
        ylo = max(self.ylo, other.ylo)
        zlo = max(self.zlo, other.zlo)
        
        xhi = min(self.xhi, other.xhi)
        yhi = min(self.yhi, other.yhi)
        zhi = min(self.zhi, other.zhi)
        
        if xlo < xhi and ylo < yhi and zlo < zhi:
            return Cuboid((xlo, xhi), (ylo, yhi), (zlo, zhi))
        else:
            return False
    
    def is_inside(self, point):
        x,y,z = point
        if (self.xlo < x < self.xhi and 
            self.ylo < y < self.yhi and 
            self.zlo < z < self.zhi):
            return True
        else:
            return False
        
    def __repr__(self):
        return (f'Cuboid(({self.xlo}, {self.xhi}), '
                f'({self.ylo}, {self.yhi}), '
                f'({self.zlo}, {self.zhi}))')
    
    def __hash__(self):
        return hash(self.ranges)

# %%
volumes = []

for i, (state, *ranges) in enumerate(steps):
    new = Cuboid(*ranges)
    for sign, other in volumes.copy():
        overlap = new.overlap(other)
        if overlap:
            # Two "positive" volumes overlapping create a negative volume
            # but a positive volume overlapping with a negative one
            # should add back a positive number
            volumes.append((-sign, overlap))
    if state:
        volumes.append((1, new))

volume = sum([c.volume*sign for sign, c in volumes])
print(volume)

# %%
raise RuntimeError
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-586-a23cb6c08fe6> in <module>
# ----> 1 raise RuntimeError
#
# RuntimeError:

# %% [markdown]
# ### Original solution - The overlaps are too complicated to keep track of (I thought)
# Instead, whenever there's an overlap, let's try to split one of the cuboitds into a few smaller ones. Then remove the overlapping part altogether.
#
# Algorithm
# - When adding a new on-cube, look for overlaps with existing on-cubes
# - For each overlap
#     - Find the cube that has at least one vertex inside the other (these vertices should be shared with the overlap cuboid)
#     - Take one such vertex and the coordinates of the outer cube
#     - Create 8 new volumes, using one of the vertex coordinates and one of the eight vertices of the outer cube
#         - Re-sort low and high coordinates to feed numbers into Cuboid class
#     - Remove the original outer volume and cuboid that's identical with the overlap (if exists)
#     - See if the inner cube overlaps with any of the new cuboids. If so, repeat the process (recursively?)
# - When adding an off-cube, do the same, except don't keep any of the non-overlapping off volumes

# %%
def split_both(c1, c2):
    new_ranges = []
    for i in range(3):
        lo1, hi1 = c1.ranges[i]
        lo2, hi2 = c2.ranges[i]
        ll = sorted(set([lo1, lo2, hi1, hi2]))
        new_r = []
        for i in range(len(ll)-1):
            new_r.append([ll[i], ll[i+1]])
        new_ranges.append(new_r)
    new_ranges

    c1_children, c2_children = [], []
    for xrange in new_ranges[0]:
        for yrange in new_ranges[1]:
            for zrange in new_ranges[2]:
                new = Cuboid(xrange, yrange, zrange)
                if new.overlap(c1):
                    c1_children.append(new)
                elif new.overlap(c2):
                    c2_children.append(new)

    return c1_children, c2_children

# %%
# %%timeit
split_both(c1, c2)
# Out:
# 99.9 µs ± 3.09 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
#steps = load_steps('day22_overlap_example.txt')
steps = load_steps()[:20]

# %%
on_cuboids = []

for i, (state, *ranges) in enumerate(steps):
    print(f'Step {i}, {len(on_cuboids)} tracked cuboids')
    
    master_new = Cuboid(*ranges)
    new_cuboids = [master_new]
    non_overlapping = set()
    
    repeat = True
    while repeat:
        repeat = False
        for other in set(on_cuboids) - non_overlapping:
            for new in new_cuboids:
                overlap = new.overlap(other)
                if overlap:
                    news, others = split_both(new, other)
                    
                    #print(f'Attempting to remove {other}')
                    on_cuboids.remove(other)
                    on_cuboids.extend(others)
                    
                    new_cuboids.remove(new)
                    new_cuboids.extend(news)
                    
                    repeat = True
                    break
            if repeat:
                break
            non_overlapping.add(other)
    if state:
        # After everything is said and done, add all the new
        # on cuboids to the global list
        on_cuboids.extend(new_cuboids)

total_volume = sum([c.volume for c in on_cuboids])
print(total_volume)
# Out:
# Step 0, 0 tracked cuboids
# Step 1, 1 tracked cuboids
# Step 2, 15 tracked cuboids
# Step 3, 63 tracked cuboids
# Step 4, 111 tracked cuboids
# Step 5, 181 tracked cuboids
# Step 6, 262 tracked cuboids
# Step 7, 479 tracked cuboids
# Step 8, 696 tracked cuboids
# Step 9, 835 tracked cuboids
# Step 10, 1043 tracked cuboids
# Step 11, 1071 tracked cuboids
# Step 12, 1580 tracked cuboids
# Step 13, 1660 tracked cuboids
# Step 14, 2392 tracked cuboids
# Step 15, 2421 tracked cuboids
# Step 16, 3212 tracked cuboids
# Step 17, 3278 tracked cuboids
# Step 18, 3793 tracked cuboids
# Step 19, 3802 tracked cuboids
# 596989

# %% [markdown]
# Try to speed it up by using a hierarchy of volumes and storing the children below the master volume...

# %%
on_cuboids = {}

for i, (state, *ranges) in enumerate(steps):
    print(f'Step {i}, {len(on_cuboids)} tracked cuboids')
    
    master_new = Cuboid(*ranges)
    new_cuboids = [master_new]
    #non_overlapping = set()
    
    repeat = True
    while repeat:
        repeat = False
        for new in new_cuboids:
            #for other in set(on_cuboids) - non_overlapping:
            for master_other in on_cuboids:
                if new.overlap(master_other):
                    for other in on_cuboids[master_other]:
                        overlap = new.overlap(other)
                        if overlap:
                            news, others = split_both(new, other)

                            on_cuboids[master_other].remove(other)
                            on_cuboids[master_other].extend(others)

                            new_cuboids.remove(new)
                            new_cuboids.extend(news)

                            repeat = True
                            break
                    if repeat:
                        break
            if repeat:
                break
            #non_overlapping.add(other)
    if state:
        # After everything is said and done, add all the new
        # on cuboids to the global list
        on_cuboids[master_new] = new_cuboids

total_volume = sum([c.volume for c in on_cuboids])
print(total_volume)
# Out:
# Step 0, 0 tracked cuboids
# Step 1, 1 tracked cuboids
# Step 2, 2 tracked cuboids
# Step 3, 3 tracked cuboids
# Step 4, 4 tracked cuboids
# Step 5, 5 tracked cuboids
# Step 6, 6 tracked cuboids
# Step 7, 7 tracked cuboids
# Step 8, 8 tracked cuboids
# Step 9, 9 tracked cuboids
# Step 10, 10 tracked cuboids
# Step 11, 10 tracked cuboids
# Step 12, 11 tracked cuboids
# Step 13, 11 tracked cuboids
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-602-39b6b87b6a65> in <module>
#      16                 if new.overlap(master_other):
#      17                     for other in on_cuboids[master_other]:
# ---> 18                         overlap = new.overlap(other)
#      19                         if overlap:
#      20                             news, others = split_both(new, other)
#
# <ipython-input-425-da8653456a80> in overlap(self, other)
#      43
#      44         xhi = min(self.xhi, other.xhi)
# ---> 45         yhi = min(self.yhi, other.yhi)
#      46         zhi = min(self.zhi, other.zhi)
#      47
#
# KeyboardInterrupt:

# %% [markdown]
# ### Old, overcomplicated (and wrong) code

# %%
counter = 0
on_cuboids = []
overlaps = []

for i, (state, *ranges) in enumerate(steps[:20]):
    if state:
        print('New on-region')
        new = Cuboid(*ranges)
        print(new)
        new_cuboids = [new]
        counter += new.volume
        print(f'Adding {new.volume} to the counter')
        
        for c_on in overlaps:
            # Check overlap with other, pre-registered overlaps
            overlap = new.overlap(c_on)
            if overlap:
                # Add back to the counter cause we'll remove it in next step
                print('Found overlap with another overlap, '
                      f'adding {overlap.volume} to counter')
                counter += overlap.volume
            
        for c_on in on_cuboids:
            # Check overlap with other on-cuboids
            overlap = new.overlap(c_on)
            if overlap:
                print('Found overlap with another on-cube, '
                      f'subtracting {overlap.volume} from the counter')
                counter -= overlap.volume
                overlaps.append(overlap)
            for c_off in c_on.offs:
                # Check overlap with off-areas of on-cuboids
                overlap2 = new.overlap(c_off)
                if overlap2:
                    print('Found overlap with an off-region, '
                          f'adding {overlap2.volume} back to the counter')
                    # If there's overlap with an off-area,
                    # Create a new independend on-cuboid
                    counter += overlap2.volume
                    new_cuboids.append(overlap2)
                    print('And creating new cuboid', overlap2)
        on_cuboids.extend(new_cuboids)
    else:
        print('New off-region')
        new_off = Cuboid(*ranges)
        print(new_off)
        new_offs = []
        for c_on in on_cuboids:
            overlap = new_off.overlap(c_on)
            if overlap:
                print('Found overlap with an on-cube, creating sub-region')
                c_on.offs.append(overlap)
                new_offs.append(overlap)
                
        print('\nChecking for overlaps with other off-regions')
        found_pairs = set()
        for i, off1 in enumerate(new_offs):
            print()
            counter -= off1.volume
            print(f'Subtracting {off1.volume} from the counter')
            for c_on in on_cuboids:
                print('Looking at off-regions added to', c_on)
                for off2 in c_on.offs:
                    print('Found off-region', off2)
                    if off1 != off2:
                        overlap = off1.overlap(off2)
                        if overlap:
                            if ((off1, off2) not in found_pairs and 
                                (off2, off1) not in found_pairs):
                                print('Found overlap with another off-region, '
                                     f'adding {overlap.volume} back to the counter')
                                counter += overlap.volume
                                found_pairs.add((off2, off1))
                                
    print(f'\nCube counter: {counter}')
    print(f'But should be {int(step_counters[i])}')
    if diff := counter - step_counters[i]:
        print(f'That\'s a difference of {diff}')
    print()
# Out:
# New on-region
# Cuboid((0, 45), (-37, 13), (-13, 32))
# Adding 101250 to the counter
#
# Cube counter: 101250
# But should be 101250
#
# New on-region
# Cuboid((-35, 20), (-9, 38), (-14, 40))
# Adding 139590 to the counter
# Found overlap with another on-cube, subtracting 19800 from the counter
#
# Cube counter: 221040
# But should be 221040
#
# New on-region
# Cuboid((-34, 21), (-25, 26), (-38, 8))
# Adding 129030 to the counter
# Found overlap with another overlap, adding 9240 to counter
# Found overlap with another on-cube, subtracting 16758 from the counter
# Found overlap with another on-cube, subtracting 41580 from the counter
#
# Cube counter: 300972
# But should be 300972
#
# New on-region
# Cuboid((-29, 20), (-43, 10), (-18, 33))
# Adding 132447 to the counter
# Found overlap with another overlap, adding 17100 to counter
# Found overlap with another overlap, adding 14700 to counter
# Found overlap with another overlap, adding 20482 to counter
# Found overlap with another on-cube, subtracting 42300 from the counter
# Found overlap with another on-cube, subtracting 43757 from the counter
# Found overlap with another on-cube, subtracting 44590 from the counter
#
# Cube counter: 355054
# But should be 347074
# That's a difference of 7980.0
#
# New on-region
# Cuboid((-34, 21), (-3, 48), (-45, 7))
# Adding 145860 to the counter
# Found overlap with another overlap, adding 6400 to counter
# Found overlap with another overlap, adding 6720 to counter
# Found overlap with another overlap, adding 32886 to counter
# Found overlap with another overlap, adding 5200 to counter
# Found overlap with another overlap, adding 13377 to counter
# Found overlap with another overlap, adding 15925 to counter
# Found overlap with another on-cube, subtracting 6720 from the counter
# Found overlap with another on-cube, subtracting 46494 from the counter
# Found overlap with another on-cube, subtracting 71775 from the counter
# Found overlap with another on-cube, subtracting 15925 from the counter
#
# Cube counter: 440508
# But should be 407551
# That's a difference of 32957.0
#
# New on-region
# Cuboid((-46, 3), (-25, 26), (-1, 48))
# Adding 122451 to the counter
# Found overlap with another overlap, adding 2178 to counter
# Found overlap with another overlap, adding 1026 to counter
# Found overlap with another overlap, adding 11655 to counter
# Found overlap with another overlap, adding 3465 to counter
# Found overlap with another overlap, adding 20672 to counter
# Found overlap with another overlap, adding 10080 to counter
# Found overlap with another overlap, adding 384 to counter
# Found overlap with another overlap, adding 8584 to counter
# Found overlap with another overlap, adding 8584 to counter
# Found overlap with another overlap, adding 3328 to counter
# Found overlap with another on-cube, subtracting 3762 from the counter
# Found overlap with another on-cube, subtracting 54530 from the counter
# Found overlap with another on-cube, subtracting 16983 from the counter
# Found overlap with another on-cube, subtracting 38080 from the counter
# Found overlap with another on-cube, subtracting 8584 from the counter
#
# Cube counter: 510976
# But should be 457344
# That's a difference of 53632.0
#
# New on-region
# Cuboid((-41, 5), (-15, 30), (-14, 37))
# Adding 105570 to the counter
# Found overlap with another overlap, adding 4950 to counter
# Found overlap with another overlap, adding 2940 to counter
# Found overlap with another overlap, adding 30030 to counter
# Found overlap with another overlap, adding 5625 to counter
# Found overlap with another overlap, adding 30362 to counter
# Found overlap with another overlap, adding 18700 to counter
# Found overlap with another overlap, adding 1600 to counter
# Found overlap with another overlap, adding 27027 to counter
# Found overlap with another overlap, adding 23751 to counter
# Found overlap with another overlap, adding 9282 to counter
# Found overlap with another overlap, adding 2772 to counter
# Found overlap with another overlap, adding 50540 to counter
# Found overlap with another overlap, adding 13653 to counter
# Found overlap with another overlap, adding 27200 to counter
# Found overlap with another overlap, adding 8584 to counter
# Found overlap with another on-cube, subtracting 6300 from the counter
# Found overlap with another on-cube, subtracting 79560 from the counter
# Found overlap with another on-cube, subtracting 35178 from the counter
# Found overlap with another on-cube, subtracting 39950 from the counter
# Found overlap with another on-cube, subtracting 27027 from the counter
# Found overlap with another on-cube, subtracting 68552 from the counter
#
# Cube counter: 616995
# But should be 461892
# That's a difference of 155103.0
#
# New on-region
# Cuboid((-49, 3), (-16, 36), (-15, 34))
# Adding 132496 to the counter
# Found overlap with another overlap, adding 2970 to counter
# Found overlap with another overlap, adding 1827 to counter
# Found overlap with another overlap, adding 28490 to counter
# Found overlap with another overlap, adding 3510 to counter
# Found overlap with another overlap, adding 28576 to counter
# Found overlap with another overlap, adding 19136 to counter
# Found overlap with another overlap, adding 960 to counter
# Found overlap with another overlap, adding 30303 to counter
# Found overlap with another overlap, adding 23606 to counter
# Found overlap with another overlap, adding 9152 to counter
# Found overlap with another overlap, adding 2871 to counter
# Found overlap with another overlap, adding 46550 to counter
# Found overlap with another overlap, adding 13986 to counter
# Found overlap with another overlap, adding 28288 to counter
# Found overlap with another overlap, adding 8584 to counter
# Found overlap with another overlap, adding 3780 to counter
# Found overlap with another overlap, adding 71136 to counter
# Found overlap with another overlap, adding 33374 to counter
# Found overlap with another overlap, adding 37600 to counter
# Found overlap with another overlap, adding 25641 to counter
# Found overlap with another overlap, adding 63140 to counter
# Found overlap with another on-cube, subtracting 3915 from the counter
# Found overlap with another on-cube, subtracting 82080 from the counter
# Found overlap with another on-cube, subtracting 35742 from the counter
# Found overlap with another on-cube, subtracting 39936 from the counter
# Found overlap with another on-cube, subtracting 31746 from the counter
# Found overlap with another on-cube, subtracting 72030 from the counter
# Found overlap with another on-cube, subtracting 95040 from the counter
#
# Cube counter: 872482
# But should be 477109
# That's a difference of 395373.0
#
# New on-region
# Cuboid((-45, 0), (-9, 46), (-12, 38))
# Adding 123750 to the counter
# Found overlap with another overlap, adding 23800 to counter
# Found overlap with another overlap, adding 24795 to counter
# Found overlap with another overlap, adding 11020 to counter
# Found overlap with another overlap, adding 26486 to counter
# Found overlap with another overlap, adding 18734 to counter
# Found overlap with another overlap, adding 7163 to counter
# Found overlap with another overlap, adding 47775 to counter
# Found overlap with another overlap, adding 10710 to counter
# Found overlap with another overlap, adding 18734 to counter
# Found overlap with another overlap, adding 7888 to counter
# Found overlap with another overlap, adding 66885 to counter
# Found overlap with another overlap, adding 23800 to counter
# Found overlap with another overlap, adding 24795 to counter
# Found overlap with another overlap, adding 21318 to counter
# Found overlap with another overlap, adding 54530 to counter
# Found overlap with another overlap, adding 72450 to counter
# Found overlap with another overlap, adding 23800 to counter
# Found overlap with another overlap, adding 24795 to counter
# Found overlap with another overlap, adding 25194 to counter
# Found overlap with another overlap, adding 55125 to counter
# Found overlap with another overlap, adding 73554 to counter
# Found overlap with another on-cube, subtracting 82250 from the counter
# Found overlap with another on-cube, subtracting 23800 from the counter
# Found overlap with another on-cube, subtracting 24795 from the counter
# Found overlap with another on-cube, subtracting 31654 from the counter
# Found overlap with another on-cube, subtracting 61425 from the counter
# Found overlap with another on-cube, subtracting 78351 from the counter
# Found overlap with another on-cube, subtracting 93150 from the counter
#
# Cube counter: 1264158
# But should be 491269
# That's a difference of 772889.0
#
# New on-region
# Cuboid((-49, -3), (-44, 8), (-41, 12))
# Adding 126776 to the counter
# Found overlap with another overlap, adding 11594 to counter
# Found overlap with another overlap, adding 11492 to counter
# Found overlap with another overlap, adding 22308 to counter
# Found overlap with another overlap, adding 7161 to counter
# Found overlap with another overlap, adding 15345 to counter
# Found overlap with another overlap, adding 7150 to counter
# Found overlap with another overlap, adding 7072 to counter
# Found overlap with another overlap, adding 9207 to counter
# Found overlap with another overlap, adding 11154 to counter
# Found overlap with another overlap, adding 2728 to counter
# Found overlap with another overlap, adding 14144 to counter
# Found overlap with another overlap, adding 15686 to counter
# Found overlap with another overlap, adding 15548 to counter
# Found overlap with another overlap, adding 7161 to counter
# Found overlap with another overlap, adding 11362 to counter
# Found overlap with another overlap, adding 14144 to counter
# Found overlap with another overlap, adding 17112 to counter
# Found overlap with another overlap, adding 16848 to counter
# Found overlap with another overlap, adding 7502 to counter
# Found overlap with another overlap, adding 13416 to counter
# Found overlap with another overlap, adding 22724 to counter
# Found overlap with another overlap, adding 13056 to counter
# Found overlap with another overlap, adding 10540 to counter
# Found overlap with another overlap, adding 10608 to counter
# Found overlap with another overlap, adding 6479 to counter
# Found overlap with another overlap, adding 9282 to counter
# Found overlap with another overlap, adding 15504 to counter
# Found overlap with another overlap, adding 17136 to counter
# Found overlap with another on-cube, subtracting 14144 from the counter
# Found overlap with another on-cube, subtracting 47058 from the counter
# Found overlap with another on-cube, subtracting 39780 from the counter
# Found overlap with another on-cube, subtracting 16368 from the counter
# Found overlap with another on-cube, subtracting 18447 from the counter
# Found overlap with another on-cube, subtracting 22724 from the counter
# Found overlap with another on-cube, subtracting 29808 from the counter
# Found overlap with another on-cube, subtracting 17136 from the counter
#
# Cube counter: 1528932
# But should be 540708
# That's a difference of 988224.0
#
# New off-region
# Cuboid((-45, -30), (-9, 4), (-30, -15))
# Found overlap with an on-cube, creating sub-region
# Found overlap with an on-cube, creating sub-region
# Found overlap with an on-cube, creating sub-region
#
# Checking for overlaps with other off-regions
#
# Subtracting 780 from the counter
# Looking at off-regions added to Cuboid((0, 45), (-37, 13), (-13, 32))
# Looking at off-regions added to Cuboid((-35, 20), (-9, 38), (-14, 40))
# Looking at off-regions added to Cuboid((-34, 21), (-25, 26), (-38, 8))
# Found off-region Cuboid((-34, -30), (-9, 4), (-30, -15))
# Looking at off-regions added to Cuboid((-29, 20), (-43, 10), (-18, 33))
# Looking at off-regions added to Cuboid((-34, 21), (-3, 48), (-45, 7))
# Found off-region Cuboid((-34, -30), (-3, 4), (-30, -15))
# Found overlap with another off-region, adding 420 back to the counter
# Looking at off-regions added to Cuboid((-46, 3), (-25, 26), (-1, 48))
# Looking at off-regions added to Cuboid((-41, 5), (-15, 30), (-14, 37))
# Looking at off-regions added to Cuboid((-49, 3), (-16, 36), (-15, 34))
# Looking at off-regions added to Cuboid((-45, 0), (-9, 46), (-12, 38))
# Looking at off-regions added to Cuboid((-49, -3), (-44, 8), (-41, 12))
# Found off-region Cuboid((-45, -30), (-9, 4), (-30, -15))
# Found overlap with another off-region, adding 780 back to the counter
#
# Subtracting 420 from the counter
# Looking at off-regions added to Cuboid((0, 45), (-37, 13), (-13, 32))
# Looking at off-regions added to Cuboid((-35, 20), (-9, 38), (-14, 40))
# Looking at off-regions added to Cuboid((-34, 21), (-25, 26), (-38, 8))
# Found off-region Cuboid((-34, -30), (-9, 4), (-30, -15))
# Looking at off-regions added to Cuboid((-29, 20), (-43, 10), (-18, 33))
# Looking at off-regions added to Cuboid((-34, 21), (-3, 48), (-45, 7))
# Found off-region Cuboid((-34, -30), (-3, 4), (-30, -15))
# Looking at off-regions added to Cuboid((-46, 3), (-25, 26), (-1, 48))
# Looking at off-regions added to Cuboid((-41, 5), (-15, 30), (-14, 37))
# Looking at off-regions added to Cuboid((-49, 3), (-16, 36), (-15, 34))
# Looking at off-regions added to Cuboid((-45, 0), (-9, 46), (-12, 38))
# Looking at off-regions added to Cuboid((-49, -3), (-44, 8), (-41, 12))
# Found off-region Cuboid((-45, -30), (-9, 4), (-30, -15))
# Found overlap with another off-region, adding 420 back to the counter
#
# Subtracting 2925 from the counter
# Looking at off-regions added to Cuboid((0, 45), (-37, 13), (-13, 32))
# Looking at off-regions added to Cuboid((-35, 20), (-9, 38), (-14, 40))
# Looking at off-regions added to Cuboid((-34, 21), (-25, 26), (-38, 8))
# Found off-region Cuboid((-34, -30), (-9, 4), (-30, -15))
# Looking at off-regions added to Cuboid((-29, 20), (-43, 10), (-18, 33))
# Looking at off-regions added to Cuboid((-34, 21), (-3, 48), (-45, 7))
# Found off-region Cuboid((-34, -30), (-3, 4), (-30, -15))
# Looking at off-regions added to Cuboid((-46, 3), (-25, 26), (-1, 48))
# Looking at off-regions added to Cuboid((-41, 5), (-15, 30), (-14, 37))
# Looking at off-regions added to Cuboid((-49, 3), (-16, 36), (-15, 34))
# Looking at off-regions added to Cuboid((-45, 0), (-9, 46), (-12, 38))
# Looking at off-regions added to Cuboid((-49, -3), (-44, 8), (-41, 12))
# Found off-region Cuboid((-45, -30), (-9, 4), (-30, -15))
#
# Cube counter: 1526427
# But should be 300972
# That's a difference of 1225455.0
#
# New on-region
# Cuboid((-38, 15), (-39, 9), (-42, 11))
# Adding 134832 to the counter
# Found overlap with another overlap, adding 6480 to counter
# Found overlap with another overlap, adding 10710 to counter
# Found overlap with another overlap, adding 19404 to counter
# Found overlap with another overlap, adding 16560 to counter
# Found overlap with another overlap, adding 19800 to counter
# Found overlap with another overlap, adding 38896 to counter
# Found overlap with another overlap, adding 3600 to counter
# Found overlap with another overlap, adding 12348 to counter
# Found overlap with another overlap, adding 26460 to counter
# Found overlap with another overlap, adding 13200 to counter
# Found overlap with another overlap, adding 1224 to counter
# Found overlap with another overlap, adding 8208 to counter
# Found overlap with another overlap, adding 11322 to counter
# Found overlap with another overlap, adding 13056 to counter
# Found overlap with another overlap, adding 3552 to counter
# Found overlap with another overlap, adding 2880 to counter
# Found overlap with another overlap, adding 18000 to counter
# Found overlap with another overlap, adding 20592 to counter
# Found overlap with another overlap, adding 20400 to counter
# Found overlap with another overlap, adding 9828 to counter
# Found overlap with another overlap, adding 11808 to counter
# Found overlap with another overlap, adding 1800 to counter
# Found overlap with another overlap, adding 17100 to counter
# Found overlap with another overlap, adding 21275 to counter
# Found overlap with another overlap, adding 20800 to counter
# Found overlap with another overlap, adding 9768 to counter
# Found overlap with another overlap, adding 12300 to counter
# Found overlap with another overlap, adding 24600 to counter
# Found overlap with another overlap, adding 14490 to counter
# Found overlap with another overlap, adding 12240 to counter
# Found overlap with another overlap, adding 12006 to counter
# Found overlap with another overlap, adding 7752 to counter
# Found overlap with another overlap, adding 8208 to counter
# Found overlap with another overlap, adding 15732 to counter
# Found overlap with another overlap, adding 15732 to counter
# Found overlap with another overlap, adding 13600 to counter
# Found overlap with another overlap, adding 47058 to counter
# Found overlap with another overlap, adding 35438 to counter
# Found overlap with another overlap, adding 16368 to counter
# Found overlap with another overlap, adding 13860 to counter
# Found overlap with another overlap, adding 20125 to counter
# Found overlap with another overlap, adding 21840 to counter
# Found overlap with another overlap, adding 13685 to counter
# Found overlap with another on-cube, subtracting 16560 from the counter
# Found overlap with another on-cube, subtracting 22500 from the counter
# Found overlap with another on-cube, subtracting 76636 from the counter
# Found overlap with an off-region, adding 780 back to the counter
# And creating new cuboid Cuboid((-34, -30), (-9, 4), (-30, -15))
# Found overlap with another on-cube, subtracting 61248 from the counter
# Found overlap with another on-cube, subtracting 28812 from the counter
# Found overlap with an off-region, adding 420 back to the counter
# And creating new cuboid Cuboid((-34, -30), (-3, 4), (-30, -15))
# Found overlap with another on-cube, subtracting 16728 from the counter
# Found overlap with another on-cube, subtracting 25800 from the counter
# Found overlap with another on-cube, subtracting 26650 from the counter
# Found overlap with another on-cube, subtracting 15732 from the counter
# Found overlap with another on-cube, subtracting 85540 from the counter
# Found overlap with an off-region, adding 1560 back to the counter
# And creating new cuboid Cuboid((-38, -30), (-9, 4), (-30, -15))
#
# Cube counter: 1951918
# But should be 548387
# That's a difference of 1403531.0
#
# New off-region
# Cuboid((-19, -2), (-21, -11), (5, 24))
# Found overlap with an on-cube, creating sub-region
# Found overlap with an on-cube, creating sub-region
# Found overlap with an on-cube, creating sub-region
# Found overlap with an on-cube, creating sub-region
# Found overlap with an on-cube, creating sub-region
# Found overlap with an on-cube, creating sub-region
# Found overlap with an on-cube, creating sub-region
#
# Checking for overlaps with other off-regions
#
# Subtracting 510 from the counter
# Looking at off-regions added to Cuboid((0, 45), (-37, 13), (-13, 32))
# Looking at off-regions added to Cuboid((-35, 20), (-9, 38), (-14, 40))
# Looking at off-regions added to Cuboid((-34, 21), (-25, 26), (-38, 8))
# Found off-region Cuboid((-34, -30), (-9, 4), (-30, -15))
# Found off-region Cuboid((-19, -2), (-21, -11), (5, 8))
# Looking at off-regions added to Cuboid((-29, 20), (-43, 10), (-18, 33))
# Found off-region Cuboid((-19, -2), (-21, -11), (5, 24))
# Found overlap with another off-region, adding 510 back to the counter
# Looking at off-regions added to Cuboid((-34, 21), (-3, 48), (-45, 7))
# Found off-region Cuboid((-34, -30), (-3, 4), (-30, -15))
# Looking at off-regions added to Cuboid((-46, 3), (-25, 26), (-1, 48))
# Found off-region Cuboid((-19, -2), (-21, -11), (5, 24))
# Found overlap with another off-region, adding 510 back to the counter
# Looking at off-regions added to Cuboid((-41, 5), (-15, 30), (-14, 37))
# Found off-region Cuboid((-19, -2), (-15, -11), (5, 24))
# Found overlap with another off-region, adding 204 back to the counter
# Looking at off-regions added to Cuboid((-49, 3), (-16, 36), (-15, 34))
# Found off-region Cuboid((-19, -2), (-16, -11), (5, 24))
# Found overlap with another off-region, adding 255 back to the counter
# Looking at off-regions added to Cuboid((-45, 0), (-9, 46), (-12, 38))
# Looking at off-regions added to Cuboid((-49, -3), (-44, 8), (-41, 12))
# Found off-region Cuboid((-45, -30), (-9, 4), (-30, -15))
# Found off-region Cuboid((-19, -3), (-21, -11), (5, 12))
# Found overlap with another off-region, adding 480 back to the counter
# Looking at off-regions added to Cuboid((-38, 15), (-39, 9), (-42, 11))
# Found off-region Cuboid((-19, -2), (-21, -11), (5, 11))
# Found overlap with another off-region, adding 510 back to the counter
# Looking at off-regions added to Cuboid((-34, -30), (-9, 4), (-30, -15))
# Looking at off-regions added to Cuboid((-34, -30), (-3, 4), (-30, -15))
# Looking at off-regions added to Cuboid((-38, -30), (-9, 4), (-30, -15))
#
# Subtracting 3230 from the counter
# Looking at off-regions added to Cuboid((0, 45), (-37, 13), (-13, 32))
# Looking at off-regions added to Cuboid((-35, 20), (-9, 38), (-14, 40))
# Looking at off-regions added to Cuboid((-34, 21), (-25, 26), (-38, 8))
# Found off-region Cuboid((-34, -30), (-9, 4), (-30, -15))
# Found off-region Cuboid((-19, -2), (-21, -11), (5, 8))
# Looking at off-regions added to Cuboid((-29, 20), (-43, 10), (-18, 33))
# Found off-region Cuboid((-19, -2), (-21, -11), (5, 24))
# Looking at off-regions added to Cuboid((-34, 21), (-3, 48), (-45, 7))
# Found off-region Cuboid((-34, -30), (-3, 4), (-30, -15))
# Looking at off-regions added to Cuboid((-46, 3), (-25, 26), (-1, 48))
# Found off-region Cuboid((-19, -2), (-21, -11), (5, 24))
# Found overlap with another off-region, adding 3230 back to the counter
# Looking at off-regions added to Cuboid((-41, 5), (-15, 30), (-14, 37))
# Found off-region Cuboid((-19, -2), (-15, -11), (5, 24))
# Found overlap with another off-region, adding 1292 back to the counter
# Looking at off-regions added to Cuboid((-49, 3), (-16, 36), (-15, 34))
# Found off-region Cuboid((-19, -2), (-16, -11), (5, 24))
# Found overlap with another off-region, adding 1615 back to the counter
# Looking at off-regions added to Cuboid((-45, 0), (-9, 46), (-12, 38))
# Looking at off-regions added to Cuboid((-49, -3), (-44, 8), (-41, 12))
# Found off-region Cuboid((-45, -30), (-9, 4), (-30, -15))
# Found off-region Cuboid((-19, -3), (-21, -11), (5, 12))
# Found overlap with another off-region, adding 1120 back to the counter
# Looking at off-regions added to Cuboid((-38, 15), (-39, 9), (-42, 11))
# Found off-region Cuboid((-19, -2), (-21, -11), (5, 11))
# Found overlap with another off-region, adding 1020 back to the counter
# Looking at off-regions added to Cuboid((-34, -30), (-9, 4), (-30, -15))
# Looking at off-regions added to Cuboid((-34, -30), (-3, 4), (-30, -15))
# Looking at off-regions added to Cuboid((-38, -30), (-9, 4), (-30, -15))
#
# Subtracting 3230 from the counter
# Looking at off-regions added to Cuboid((0, 45), (-37, 13), (-13, 32))
# Looking at off-regions added to Cuboid((-35, 20), (-9, 38), (-14, 40))
# Looking at off-regions added to Cuboid((-34, 21), (-25, 26), (-38, 8))
# Found off-region Cuboid((-34, -30), (-9, 4), (-30, -15))
# Found off-region Cuboid((-19, -2), (-21, -11), (5, 8))
# Looking at off-regions added to Cuboid((-29, 20), (-43, 10), (-18, 33))
# Found off-region Cuboid((-19, -2), (-21, -11), (5, 24))
# Looking at off-regions added to Cuboid((-34, 21), (-3, 48), (-45, 7))
# Found off-region Cuboid((-34, -30), (-3, 4), (-30, -15))
# Looking at off-regions added to Cuboid((-46, 3), (-25, 26), (-1, 48))
# Found off-region Cuboid((-19, -2), (-21, -11), (5, 24))
# Looking at off-regions added to Cuboid((-41, 5), (-15, 30), (-14, 37))
# Found off-region Cuboid((-19, -2), (-15, -11), (5, 24))
# Found overlap with another off-region, adding 1292 back to the counter
# Looking at off-regions added to Cuboid((-49, 3), (-16, 36), (-15, 34))
# Found off-region Cuboid((-19, -2), (-16, -11), (5, 24))
# Found overlap with another off-region, adding 1615 back to the counter
# Looking at off-regions added to Cuboid((-45, 0), (-9, 46), (-12, 38))
# Looking at off-regions added to Cuboid((-49, -3), (-44, 8), (-41, 12))
# Found off-region Cuboid((-45, -30), (-9, 4), (-30, -15))
# Found off-region Cuboid((-19, -3), (-21, -11), (5, 12))
# Found overlap with another off-region, adding 1120 back to the counter
# Looking at off-regions added to Cuboid((-38, 15), (-39, 9), (-42, 11))
# Found off-region Cuboid((-19, -2), (-21, -11), (5, 11))
# Found overlap with another off-region, adding 1020 back to the counter
# Looking at off-regions added to Cuboid((-34, -30), (-9, 4), (-30, -15))
# Looking at off-regions added to Cuboid((-34, -30), (-3, 4), (-30, -15))
# Looking at off-regions added to Cuboid((-38, -30), (-9, 4), (-30, -15))
#
# Subtracting 1292 from the counter
# Looking at off-regions added to Cuboid((0, 45), (-37, 13), (-13, 32))
# Looking at off-regions added to Cuboid((-35, 20), (-9, 38), (-14, 40))
# Looking at off-regions added to Cuboid((-34, 21), (-25, 26), (-38, 8))
# Found off-region Cuboid((-34, -30), (-9, 4), (-30, -15))
# Found off-region Cuboid((-19, -2), (-21, -11), (5, 8))
# Looking at off-regions added to Cuboid((-29, 20), (-43, 10), (-18, 33))
# Found off-region Cuboid((-19, -2), (-21, -11), (5, 24))
# Looking at off-regions added to Cuboid((-34, 21), (-3, 48), (-45, 7))
# Found off-region Cuboid((-34, -30), (-3, 4), (-30, -15))
# Looking at off-regions added to Cuboid((-46, 3), (-25, 26), (-1, 48))
# Found off-region Cuboid((-19, -2), (-21, -11), (5, 24))
# Looking at off-regions added to Cuboid((-41, 5), (-15, 30), (-14, 37))
# Found off-region Cuboid((-19, -2), (-15, -11), (5, 24))
# Looking at off-regions added to Cuboid((-49, 3), (-16, 36), (-15, 34))
# Found off-region Cuboid((-19, -2), (-16, -11), (5, 24))
# Found overlap with another off-region, adding 1292 back to the counter
# Looking at off-regions added to Cuboid((-45, 0), (-9, 46), (-12, 38))
# Looking at off-regions added to Cuboid((-49, -3), (-44, 8), (-41, 12))
# Found off-region Cuboid((-45, -30), (-9, 4), (-30, -15))
# Found off-region Cuboid((-19, -3), (-21, -11), (5, 12))
# Found overlap with another off-region, adding 448 back to the counter
# Looking at off-regions added to Cuboid((-38, 15), (-39, 9), (-42, 11))
# Found off-region Cuboid((-19, -2), (-21, -11), (5, 11))
# Found overlap with another off-region, adding 408 back to the counter
# Looking at off-regions added to Cuboid((-34, -30), (-9, 4), (-30, -15))
# Looking at off-regions added to Cuboid((-34, -30), (-3, 4), (-30, -15))
# Looking at off-regions added to Cuboid((-38, -30), (-9, 4), (-30, -15))
#
# Subtracting 1615 from the counter
# Looking at off-regions added to Cuboid((0, 45), (-37, 13), (-13, 32))
# Looking at off-regions added to Cuboid((-35, 20), (-9, 38), (-14, 40))
# Looking at off-regions added to Cuboid((-34, 21), (-25, 26), (-38, 8))
# Found off-region Cuboid((-34, -30), (-9, 4), (-30, -15))
# Found off-region Cuboid((-19, -2), (-21, -11), (5, 8))
# Looking at off-regions added to Cuboid((-29, 20), (-43, 10), (-18, 33))
# Found off-region Cuboid((-19, -2), (-21, -11), (5, 24))
# Looking at off-regions added to Cuboid((-34, 21), (-3, 48), (-45, 7))
# Found off-region Cuboid((-34, -30), (-3, 4), (-30, -15))
# Looking at off-regions added to Cuboid((-46, 3), (-25, 26), (-1, 48))
# Found off-region Cuboid((-19, -2), (-21, -11), (5, 24))
# Looking at off-regions added to Cuboid((-41, 5), (-15, 30), (-14, 37))
# Found off-region Cuboid((-19, -2), (-15, -11), (5, 24))
# Looking at off-regions added to Cuboid((-49, 3), (-16, 36), (-15, 34))
# Found off-region Cuboid((-19, -2), (-16, -11), (5, 24))
# Looking at off-regions added to Cuboid((-45, 0), (-9, 46), (-12, 38))
# Looking at off-regions added to Cuboid((-49, -3), (-44, 8), (-41, 12))
# Found off-region Cuboid((-45, -30), (-9, 4), (-30, -15))
# Found off-region Cuboid((-19, -3), (-21, -11), (5, 12))
# Found overlap with another off-region, adding 560 back to the counter
# Looking at off-regions added to Cuboid((-38, 15), (-39, 9), (-42, 11))
# Found off-region Cuboid((-19, -2), (-21, -11), (5, 11))
# Found overlap with another off-region, adding 510 back to the counter
# Looking at off-regions added to Cuboid((-34, -30), (-9, 4), (-30, -15))
# Looking at off-regions added to Cuboid((-34, -30), (-3, 4), (-30, -15))
# Looking at off-regions added to Cuboid((-38, -30), (-9, 4), (-30, -15))
#
# Subtracting 1120 from the counter
# Looking at off-regions added to Cuboid((0, 45), (-37, 13), (-13, 32))
# Looking at off-regions added to Cuboid((-35, 20), (-9, 38), (-14, 40))
# Looking at off-regions added to Cuboid((-34, 21), (-25, 26), (-38, 8))
# Found off-region Cuboid((-34, -30), (-9, 4), (-30, -15))
# Found off-region Cuboid((-19, -2), (-21, -11), (5, 8))
# Looking at off-regions added to Cuboid((-29, 20), (-43, 10), (-18, 33))
# Found off-region Cuboid((-19, -2), (-21, -11), (5, 24))
# Looking at off-regions added to Cuboid((-34, 21), (-3, 48), (-45, 7))
# Found off-region Cuboid((-34, -30), (-3, 4), (-30, -15))
# Looking at off-regions added to Cuboid((-46, 3), (-25, 26), (-1, 48))
# Found off-region Cuboid((-19, -2), (-21, -11), (5, 24))
# Looking at off-regions added to Cuboid((-41, 5), (-15, 30), (-14, 37))
# Found off-region Cuboid((-19, -2), (-15, -11), (5, 24))
# Looking at off-regions added to Cuboid((-49, 3), (-16, 36), (-15, 34))
# Found off-region Cuboid((-19, -2), (-16, -11), (5, 24))
# Looking at off-regions added to Cuboid((-45, 0), (-9, 46), (-12, 38))
# Looking at off-regions added to Cuboid((-49, -3), (-44, 8), (-41, 12))
# Found off-region Cuboid((-45, -30), (-9, 4), (-30, -15))
# Found off-region Cuboid((-19, -3), (-21, -11), (5, 12))
# Looking at off-regions added to Cuboid((-38, 15), (-39, 9), (-42, 11))
# Found off-region Cuboid((-19, -2), (-21, -11), (5, 11))
# Found overlap with another off-region, adding 960 back to the counter
# Looking at off-regions added to Cuboid((-34, -30), (-9, 4), (-30, -15))
# Looking at off-regions added to Cuboid((-34, -30), (-3, 4), (-30, -15))
# Looking at off-regions added to Cuboid((-38, -30), (-9, 4), (-30, -15))
#
# Subtracting 1020 from the counter
# Looking at off-regions added to Cuboid((0, 45), (-37, 13), (-13, 32))
# Looking at off-regions added to Cuboid((-35, 20), (-9, 38), (-14, 40))
# Looking at off-regions added to Cuboid((-34, 21), (-25, 26), (-38, 8))
# Found off-region Cuboid((-34, -30), (-9, 4), (-30, -15))
# Found off-region Cuboid((-19, -2), (-21, -11), (5, 8))
# Looking at off-regions added to Cuboid((-29, 20), (-43, 10), (-18, 33))
# Found off-region Cuboid((-19, -2), (-21, -11), (5, 24))
# Looking at off-regions added to Cuboid((-34, 21), (-3, 48), (-45, 7))
# Found off-region Cuboid((-34, -30), (-3, 4), (-30, -15))
# Looking at off-regions added to Cuboid((-46, 3), (-25, 26), (-1, 48))
# Found off-region Cuboid((-19, -2), (-21, -11), (5, 24))
# Looking at off-regions added to Cuboid((-41, 5), (-15, 30), (-14, 37))
# Found off-region Cuboid((-19, -2), (-15, -11), (5, 24))
# Looking at off-regions added to Cuboid((-49, 3), (-16, 36), (-15, 34))
# Found off-region Cuboid((-19, -2), (-16, -11), (5, 24))
# Looking at off-regions added to Cuboid((-45, 0), (-9, 46), (-12, 38))
# Looking at off-regions added to Cuboid((-49, -3), (-44, 8), (-41, 12))
# Found off-region Cuboid((-45, -30), (-9, 4), (-30, -15))
# Found off-region Cuboid((-19, -3), (-21, -11), (5, 12))
# Looking at off-regions added to Cuboid((-38, 15), (-39, 9), (-42, 11))
# Found off-region Cuboid((-19, -2), (-21, -11), (5, 11))
# Looking at off-regions added to Cuboid((-34, -30), (-9, 4), (-30, -15))
# Looking at off-regions added to Cuboid((-34, -30), (-3, 4), (-30, -15))
# Looking at off-regions added to Cuboid((-38, -30), (-9, 4), (-30, -15))
#
# Cube counter: 1959872
# But should be 461892
# That's a difference of 1497980.0
#
# New on-region
# Cuboid((-35, 14), (-34, 17), (-25, 30))
# Adding 137445 to the counter
# Found overlap with another overlap, adding 13244 to counter
# Found overlap with another overlap, adding 11172 to counter
# Found overlap with another overlap, adding 27456 to counter
# Found overlap with another overlap, adding 26488 to counter
# Found overlap with another overlap, adding 35948 to counter
# Found overlap with another overlap, adding 39130 to counter
# Found overlap with another overlap, adding 4480 to counter
# Found overlap with another overlap, adding 20160 to counter
# Found overlap with another overlap, adding 30720 to counter
# Found overlap with another overlap, adding 13975 to counter
# Found overlap with another overlap, adding 3534 to counter
# Found overlap with another overlap, adding 30628 to counter
# Found overlap with another overlap, adding 13986 to counter
# Found overlap with another overlap, adding 34720 to counter
# Found overlap with another overlap, adding 5920 to counter
# Found overlap with another overlap, adding 6020 to counter
# Found overlap with another overlap, adding 45760 to counter
# Found overlap with another overlap, adding 27456 to counter
# Found overlap with another overlap, adding 37400 to counter
# Found overlap with another overlap, adding 16380 to counter
# Found overlap with another overlap, adding 37696 to counter
# Found overlap with another overlap, adding 3741 to counter
# Found overlap with another overlap, adding 43472 to counter
# Found overlap with another overlap, adding 28083 to counter
# Found overlap with another overlap, adding 37440 to counter
# Found overlap with another overlap, adding 16280 to counter
# Found overlap with another overlap, adding 38874 to counter
# Found overlap with another overlap, adding 53504 to counter
# Found overlap with another overlap, adding 38220 to counter
# Found overlap with another overlap, adding 17680 to counter
# Found overlap with another overlap, adding 23142 to counter
# Found overlap with another overlap, adding 12920 to counter
# Found overlap with another overlap, adding 28210 to counter
# Found overlap with another overlap, adding 38220 to counter
# Found overlap with another overlap, adding 38220 to counter
# Found overlap with another overlap, adding 14144 to counter
# Found overlap with another overlap, adding 33759 to counter
# Found overlap with another overlap, adding 32760 to counter
# Found overlap with another overlap, adding 10912 to counter
# Found overlap with another overlap, adding 13728 to counter
# Found overlap with another overlap, adding 19136 to counter
# Found overlap with another overlap, adding 20736 to counter
# Found overlap with another overlap, adding 13056 to counter
# Found overlap with another overlap, adding 14448 to counter
# Found overlap with another overlap, adding 22050 to counter
# Found overlap with another overlap, adding 53856 to counter
# Found overlap with another overlap, adding 53621 to counter
# Found overlap with another overlap, adding 18432 to counter
# Found overlap with another overlap, adding 15504 to counter
# Found overlap with another overlap, adding 24000 to counter
# Found overlap with another overlap, adding 24700 to counter
# Found overlap with another overlap, adding 14490 to counter
# Found overlap with another overlap, adding 48384 to counter
# Found overlap with another on-cube, subtracting 28294 from the counter
# Found overlap with another on-cube, subtracting 56056 from the counter
# Found overlap with another on-cube, subtracting 66528 from the counter
# Found overlap with an off-region, adding 520 back to the counter
# And creating new cuboid Cuboid((-34, -30), (-9, 4), (-25, -15))
# Found overlap with an off-region, adding 510 back to the counter
# And creating new cuboid Cuboid((-19, -2), (-21, -11), (5, 8))
# Found overlap with another on-cube, subtracting 90816 from the counter
# Found overlap with an off-region, adding 3230 back to the counter
# And creating new cuboid Cuboid((-19, -2), (-21, -11), (5, 24))
# Found overlap with another on-cube, subtracting 30720 from the counter
# Found overlap with an off-region, adding 280 back to the counter
# And creating new cuboid Cuboid((-34, -30), (-3, 4), (-25, -15))
# Found overlap with another on-cube, subtracting 49476 from the counter
# Found overlap with an off-region, adding 3230 back to the counter
# And creating new cuboid Cuboid((-19, -2), (-21, -11), (5, 24))
# Found overlap with another on-cube, subtracting 56320 from the counter
# Found overlap with an off-region, adding 1292 back to the counter
# And creating new cuboid Cuboid((-19, -2), (-15, -11), (5, 24))
# Found overlap with another on-cube, subtracting 56430 from the counter
# Found overlap with an off-region, adding 1615 back to the counter
# And creating new cuboid Cuboid((-19, -2), (-16, -11), (5, 24))
# Found overlap with another on-cube, subtracting 38220 from the counter
# Found overlap with another on-cube, subtracting 49728 from the counter
# Found overlap with an off-region, adding 650 back to the counter
# And creating new cuboid Cuboid((-35, -30), (-9, 4), (-25, -15))
# Found overlap with an off-region, adding 1120 back to the counter
# And creating new cuboid Cuboid((-19, -3), (-21, -11), (5, 12))
# Found overlap with another on-cube, subtracting 75852 from the counter
# Found overlap with an off-region, adding 1020 back to the counter
# And creating new cuboid Cuboid((-19, -2), (-21, -11), (5, 11))
# Found overlap with another on-cube, subtracting 520 from the counter
# Found overlap with another on-cube, subtracting 280 from the counter
# Found overlap with another on-cube, subtracting 650 from the counter
#
# Cube counter: 2858889
# But should be 549439
# That's a difference of 2309450.0
#
# New off-region
# Cuboid((-46, -27), (-46, -35), (-42, -30))
# Found overlap with an on-cube, creating sub-region
# Found overlap with an on-cube, creating sub-region
#
# Checking for overlaps with other off-regions
#
# Subtracting 1881 from the counter
# Looking at off-regions added to Cuboid((0, 45), (-37, 13), (-13, 32))
# Looking at off-regions added to Cuboid((-35, 20), (-9, 38), (-14, 40))
# Looking at off-regions added to Cuboid((-34, 21), (-25, 26), (-38, 8))
# Found off-region Cuboid((-34, -30), (-9, 4), (-30, -15))
# Found off-region Cuboid((-19, -2), (-21, -11), (5, 8))
# Looking at off-regions added to Cuboid((-29, 20), (-43, 10), (-18, 33))
# Found off-region Cuboid((-19, -2), (-21, -11), (5, 24))
# Looking at off-regions added to Cuboid((-34, 21), (-3, 48), (-45, 7))
# Found off-region Cuboid((-34, -30), (-3, 4), (-30, -15))
# Looking at off-regions added to Cuboid((-46, 3), (-25, 26), (-1, 48))
# Found off-region Cuboid((-19, -2), (-21, -11), (5, 24))
# Looking at off-regions added to Cuboid((-41, 5), (-15, 30), (-14, 37))
# Found off-region Cuboid((-19, -2), (-15, -11), (5, 24))
# Looking at off-regions added to Cuboid((-49, 3), (-16, 36), (-15, 34))
# Found off-region Cuboid((-19, -2), (-16, -11), (5, 24))
# Looking at off-regions added to Cuboid((-45, 0), (-9, 46), (-12, 38))
# Looking at off-regions added to Cuboid((-49, -3), (-44, 8), (-41, 12))
# Found off-region Cuboid((-45, -30), (-9, 4), (-30, -15))
# Found off-region Cuboid((-19, -3), (-21, -11), (5, 12))
# Found off-region Cuboid((-46, -27), (-44, -35), (-41, -30))
# Looking at off-regions added to Cuboid((-38, 15), (-39, 9), (-42, 11))
# Found off-region Cuboid((-19, -2), (-21, -11), (5, 11))
# Found off-region Cuboid((-38, -27), (-39, -35), (-42, -30))
# Found overlap with another off-region, adding 484 back to the counter
# Looking at off-regions added to Cuboid((-34, -30), (-9, 4), (-30, -15))
# Looking at off-regions added to Cuboid((-34, -30), (-3, 4), (-30, -15))
# Looking at off-regions added to Cuboid((-38, -30), (-9, 4), (-30, -15))
# Looking at off-regions added to Cuboid((-35, 14), (-34, 17), (-25, 30))
# Looking at off-regions added to Cuboid((-34, -30), (-9, 4), (-25, -15))
# Looking at off-regions added to Cuboid((-19, -2), (-21, -11), (5, 8))
# Looking at off-regions added to Cuboid((-19, -2), (-21, -11), (5, 24))
# Looking at off-regions added to Cuboid((-34, -30), (-3, 4), (-25, -15))
# Looking at off-regions added to Cuboid((-19, -2), (-21, -11), (5, 24))
# Looking at off-regions added to Cuboid((-19, -2), (-15, -11), (5, 24))
# Looking at off-regions added to Cuboid((-19, -2), (-16, -11), (5, 24))
# Looking at off-regions added to Cuboid((-35, -30), (-9, 4), (-25, -15))
# Looking at off-regions added to Cuboid((-19, -3), (-21, -11), (5, 12))
# Looking at off-regions added to Cuboid((-19, -2), (-21, -11), (5, 11))
#
# Subtracting 528 from the counter
# Looking at off-regions added to Cuboid((0, 45), (-37, 13), (-13, 32))
# Looking at off-regions added to Cuboid((-35, 20), (-9, 38), (-14, 40))
# Looking at off-regions added to Cuboid((-34, 21), (-25, 26), (-38, 8))
# Found off-region Cuboid((-34, -30), (-9, 4), (-30, -15))
# Found off-region Cuboid((-19, -2), (-21, -11), (5, 8))
# Looking at off-regions added to Cuboid((-29, 20), (-43, 10), (-18, 33))
# Found off-region Cuboid((-19, -2), (-21, -11), (5, 24))
# Looking at off-regions added to Cuboid((-34, 21), (-3, 48), (-45, 7))
# Found off-region Cuboid((-34, -30), (-3, 4), (-30, -15))
# Looking at off-regions added to Cuboid((-46, 3), (-25, 26), (-1, 48))
# Found off-region Cuboid((-19, -2), (-21, -11), (5, 24))
# Looking at off-regions added to Cuboid((-41, 5), (-15, 30), (-14, 37))
# Found off-region Cuboid((-19, -2), (-15, -11), (5, 24))
# Looking at off-regions added to Cuboid((-49, 3), (-16, 36), (-15, 34))
# Found off-region Cuboid((-19, -2), (-16, -11), (5, 24))
# Looking at off-regions added to Cuboid((-45, 0), (-9, 46), (-12, 38))
# Looking at off-regions added to Cuboid((-49, -3), (-44, 8), (-41, 12))
# Found off-region Cuboid((-45, -30), (-9, 4), (-30, -15))
# Found off-region Cuboid((-19, -3), (-21, -11), (5, 12))
# Found off-region Cuboid((-46, -27), (-44, -35), (-41, -30))
# Looking at off-regions added to Cuboid((-38, 15), (-39, 9), (-42, 11))
# Found off-region Cuboid((-19, -2), (-21, -11), (5, 11))
# Found off-region Cuboid((-38, -27), (-39, -35), (-42, -30))
# Looking at off-regions added to Cuboid((-34, -30), (-9, 4), (-30, -15))
# Looking at off-regions added to Cuboid((-34, -30), (-3, 4), (-30, -15))
# Looking at off-regions added to Cuboid((-38, -30), (-9, 4), (-30, -15))
# Looking at off-regions added to Cuboid((-35, 14), (-34, 17), (-25, 30))
# Looking at off-regions added to Cuboid((-34, -30), (-9, 4), (-25, -15))
# Looking at off-regions added to Cuboid((-19, -2), (-21, -11), (5, 8))
# Looking at off-regions added to Cuboid((-19, -2), (-21, -11), (5, 24))
# Looking at off-regions added to Cuboid((-34, -30), (-3, 4), (-25, -15))
# Looking at off-regions added to Cuboid((-19, -2), (-21, -11), (5, 24))
# Looking at off-regions added to Cuboid((-19, -2), (-15, -11), (5, 24))
# Looking at off-regions added to Cuboid((-19, -2), (-16, -11), (5, 24))
# Looking at off-regions added to Cuboid((-35, -30), (-9, 4), (-25, -15))
# Looking at off-regions added to Cuboid((-19, -3), (-21, -11), (5, 12))
# Looking at off-regions added to Cuboid((-19, -2), (-21, -11), (5, 11))
#
# Cube counter: 2856964
# But should be 221040
# That's a difference of 2635924.0
#
# New on-region
# Cuboid((-19, 29), (-47, 0), (-35, 13))
# Adding 108288 to the counter
# Found overlap with another overlap, adding 4680 to counter
# Found overlap with another overlap, adding 11025 to counter
# Found overlap with another overlap, adding 7722 to counter
# Found overlap with another overlap, adding 19240 to counter
# Found overlap with another overlap, adding 9477 to counter
# Found overlap with another overlap, adding 25350 to counter
# Found overlap with another overlap, adding 1260 to counter
# Found overlap with another overlap, adding 2457 to counter
# Found overlap with another overlap, adding 5040 to counter
# Found overlap with another overlap, adding 2925 to counter
# Found overlap with another overlap, adding 1050 to counter
# Found overlap with another overlap, adding 2772 to counter
# Found overlap with another overlap, adding 4950 to counter
# Found overlap with another overlap, adding 7700 to counter
# Found overlap with another overlap, adding 528 to counter
# Found overlap with another overlap, adding 1950 to counter
# Found overlap with another overlap, adding 5832 to counter
# Found overlap with another overlap, adding 7920 to counter
# Found overlap with another overlap, adding 9720 to counter
# Found overlap with another overlap, adding 1512 to counter
# Found overlap with another overlap, adding 4620 to counter
# Found overlap with another overlap, adding 1248 to counter
# Found overlap with another overlap, adding 5346 to counter
# Found overlap with another overlap, adding 8096 to counter
# Found overlap with another overlap, adding 9856 to counter
# Found overlap with another overlap, adding 1452 to counter
# Found overlap with another overlap, adding 4928 to counter
# Found overlap with another overlap, adding 8910 to counter
# Found overlap with another overlap, adding 4275 to counter
# Found overlap with another overlap, adding 3420 to counter
# Found overlap with another overlap, adding 4275 to counter
# Found overlap with another overlap, adding 1083 to counter
# Found overlap with another overlap, adding 2394 to counter
# Found overlap with another overlap, adding 4275 to counter
# Found overlap with another overlap, adding 4275 to counter
# Found overlap with another overlap, adding 3744 to counter
# Found overlap with another overlap, adding 17200 to counter
# Found overlap with another overlap, adding 20640 to counter
# Found overlap with another overlap, adding 2016 to counter
# Found overlap with another overlap, adding 5200 to counter
# Found overlap with another overlap, adding 6240 to counter
# Found overlap with another overlap, adding 6912 to counter
# Found overlap with another overlap, adding 3456 to counter
# Found overlap with another overlap, adding 13320 to counter
# Found overlap with another overlap, adding 7650 to counter
# Found overlap with another overlap, adding 36550 to counter
# Found overlap with another overlap, adding 38454 to counter
# Found overlap with another overlap, adding 4284 to counter
# Found overlap with another overlap, adding 6600 to counter
# Found overlap with another overlap, adding 9000 to counter
# Found overlap with another overlap, adding 9152 to counter
# Found overlap with another overlap, adding 3933 to counter
# Found overlap with another overlap, adding 28704 to counter
# Found overlap with another overlap, adding 12376 to counter
# Found overlap with another overlap, adding 8019 to counter
# Found overlap with another overlap, adding 27225 to counter
# Found overlap with another overlap, adding 34782 to counter
# Found overlap with another overlap, adding 3168 to counter
# Found overlap with another overlap, adding 7700 to counter
# Found overlap with another overlap, adding 9720 to counter
# Found overlap with another overlap, adding 9856 to counter
# Found overlap with another overlap, adding 4275 to counter
# Found overlap with another overlap, adding 20128 to counter
# Found overlap with another overlap, adding 40392 to counter
# Found overlap with another on-cube, subtracting 27898 from the counter
# Found overlap with another on-cube, subtracting 9477 from the counter
# Found overlap with another on-cube, subtracting 43000 from the counter
# Found overlap with an off-region, adding 510 back to the counter
# And creating new cuboid Cuboid((-19, -2), (-21, -11), (5, 8))
# Found overlap with another on-cube, subtracting 51987 from the counter
# Found overlap with an off-region, adding 1360 back to the counter
# And creating new cuboid Cuboid((-19, -2), (-21, -11), (5, 13))
# Found overlap with another on-cube, subtracting 5040 from the counter
# Found overlap with another on-cube, subtracting 7700 from the counter
# Found overlap with an off-region, adding 1360 back to the counter
# And creating new cuboid Cuboid((-19, -2), (-21, -11), (5, 13))
# Found overlap with another on-cube, subtracting 9720 from the counter
# Found overlap with an off-region, adding 544 back to the counter
# And creating new cuboid Cuboid((-19, -2), (-15, -11), (5, 13))
# Found overlap with another on-cube, subtracting 9856 from the counter
# Found overlap with an off-region, adding 680 back to the counter
# And creating new cuboid Cuboid((-19, -2), (-16, -11), (5, 13))
# Found overlap with another on-cube, subtracting 4275 from the counter
# Found overlap with another on-cube, subtracting 33088 from the counter
# Found overlap with an off-region, adding 1120 back to the counter
# And creating new cuboid Cuboid((-19, -3), (-21, -11), (5, 12))
# Found overlap with another on-cube, subtracting 60996 from the counter
# Found overlap with an off-region, adding 1020 back to the counter
# And creating new cuboid Cuboid((-19, -2), (-21, -11), (5, 11))
# Found overlap with another on-cube, subtracting 42636 from the counter
# Found overlap with another on-cube, subtracting 510 from the counter
# Found overlap with another on-cube, subtracting 1360 from the counter
# Found overlap with another on-cube, subtracting 1360 from the counter
# Found overlap with another on-cube, subtracting 544 from the counter
# Found overlap with another on-cube, subtracting 680 from the counter
# ...
# Looking at off-regions added to Cuboid((-35, 20), (-9, 38), (-14, 40))
# Found off-region Cuboid((19, 20), (-9, -6), (-14, -10))
# Looking at off-regions added to Cuboid((-34, 21), (-25, 26), (-38, 8))
# Found off-region Cuboid((-34, -30), (-9, 4), (-30, -15))
# Found off-region Cuboid((-19, -2), (-21, -11), (5, 8))
# Found off-region Cuboid((19, 21), (-22, -6), (-30, -10))
# Looking at off-regions added to Cuboid((-29, 20), (-43, 10), (-18, 33))
# Found off-region Cuboid((-19, -2), (-21, -11), (5, 24))
# Found off-region Cuboid((19, 20), (-22, -6), (-18, -10))
# Looking at off-regions added to Cuboid((-34, 21), (-3, 48), (-45, 7))
# Found off-region Cuboid((-34, -30), (-3, 4), (-30, -15))
# Looking at off-regions added to Cuboid((-46, 3), (-25, 26), (-1, 48))
# Found off-region Cuboid((-19, -2), (-21, -11), (5, 24))
# Looking at off-regions added to Cuboid((-41, 5), (-15, 30), (-14, 37))
# Found off-region Cuboid((-19, -2), (-15, -11), (5, 24))
# Looking at off-regions added to Cuboid((-49, 3), (-16, 36), (-15, 34))
# Found off-region Cuboid((-19, -2), (-16, -11), (5, 24))
# Looking at off-regions added to Cuboid((-45, 0), (-9, 46), (-12, 38))
# Looking at off-regions added to Cuboid((-49, -3), (-44, 8), (-41, 12))
# Found off-region Cuboid((-45, -30), (-9, 4), (-30, -15))
# Found off-region Cuboid((-19, -3), (-21, -11), (5, 12))
# Found off-region Cuboid((-46, -27), (-44, -35), (-41, -30))
# Found overlap with another off-region, adding 192 back to the counter
# Found off-region Cuboid((-31, -19), (-41, -31), (-38, -25))
# Looking at off-regions added to Cuboid((-38, 15), (-39, 9), (-42, 11))
# Found off-region Cuboid((-19, -2), (-21, -11), (5, 11))
# Found off-region Cuboid((-38, -27), (-39, -35), (-42, -30))
# Found overlap with another off-region, adding 128 back to the counter
# Found off-region Cuboid((-31, -19), (-39, -31), (-38, -25))
# Found overlap with another off-region, adding 1248 back to the counter
# Looking at off-regions added to Cuboid((-34, -30), (-9, 4), (-30, -15))
# Looking at off-regions added to Cuboid((-34, -30), (-3, 4), (-30, -15))
# Looking at off-regions added to Cuboid((-38, -30), (-9, 4), (-30, -15))
# Looking at off-regions added to Cuboid((-35, 14), (-34, 17), (-25, 30))
# Looking at off-regions added to Cuboid((-34, -30), (-9, 4), (-25, -15))
# Looking at off-regions added to Cuboid((-19, -2), (-21, -11), (5, 8))
# Looking at off-regions added to Cuboid((-19, -2), (-21, -11), (5, 24))
# Looking at off-regions added to Cuboid((-34, -30), (-3, 4), (-25, -15))
# Looking at off-regions added to Cuboid((-19, -2), (-21, -11), (5, 24))
# Looking at off-regions added to Cuboid((-19, -2), (-15, -11), (5, 24))
# Looking at off-regions added to Cuboid((-19, -2), (-16, -11), (5, 24))
# Looking at off-regions added to Cuboid((-35, -30), (-9, 4), (-25, -15))
# Looking at off-regions added to Cuboid((-19, -3), (-21, -11), (5, 12))
# Looking at off-regions added to Cuboid((-19, -2), (-21, -11), (5, 11))
# Looking at off-regions added to Cuboid((-19, 29), (-47, 0), (-35, 13))
# Found off-region Cuboid((19, 29), (-22, -6), (-30, -10))
# Looking at off-regions added to Cuboid((-19, -2), (-21, -11), (5, 8))
# Looking at off-regions added to Cuboid((-19, -2), (-21, -11), (5, 13))
# Looking at off-regions added to Cuboid((-19, -2), (-21, -11), (5, 13))
# Looking at off-regions added to Cuboid((-19, -2), (-15, -11), (5, 13))
# Looking at off-regions added to Cuboid((-19, -2), (-16, -11), (5, 13))
# Looking at off-regions added to Cuboid((-19, -3), (-21, -11), (5, 12))
# Looking at off-regions added to Cuboid((-19, -2), (-21, -11), (5, 11))
# Looking at off-regions added to Cuboid((-13, 37), (-9, 42), (-12, 37))
# Looking at off-regions added to Cuboid((19, 32), (-9, -6), (-12, -10))
# Looking at off-regions added to Cuboid((19, 20), (-9, -6), (-12, -10))
# Looking at off-regions added to Cuboid((19, 21), (-9, -6), (-12, -10))
# Looking at off-regions added to Cuboid((19, 20), (-9, -6), (-12, -10))
# Looking at off-regions added to Cuboid((19, 29), (-9, -6), (-12, -10))
#
# Subtracting 1248 from the counter
# Looking at off-regions added to Cuboid((0, 45), (-37, 13), (-13, 32))
# Found off-region Cuboid((19, 32), (-22, -6), (-13, -10))
# Looking at off-regions added to Cuboid((-35, 20), (-9, 38), (-14, 40))
# Found off-region Cuboid((19, 20), (-9, -6), (-14, -10))
# Looking at off-regions added to Cuboid((-34, 21), (-25, 26), (-38, 8))
# Found off-region Cuboid((-34, -30), (-9, 4), (-30, -15))
# Found off-region Cuboid((-19, -2), (-21, -11), (5, 8))
# Found off-region Cuboid((19, 21), (-22, -6), (-30, -10))
# Looking at off-regions added to Cuboid((-29, 20), (-43, 10), (-18, 33))
# Found off-region Cuboid((-19, -2), (-21, -11), (5, 24))
# Found off-region Cuboid((19, 20), (-22, -6), (-18, -10))
# Looking at off-regions added to Cuboid((-34, 21), (-3, 48), (-45, 7))
# Found off-region Cuboid((-34, -30), (-3, 4), (-30, -15))
# Looking at off-regions added to Cuboid((-46, 3), (-25, 26), (-1, 48))
# Found off-region Cuboid((-19, -2), (-21, -11), (5, 24))
# Looking at off-regions added to Cuboid((-41, 5), (-15, 30), (-14, 37))
# Found off-region Cuboid((-19, -2), (-15, -11), (5, 24))
# Looking at off-regions added to Cuboid((-49, 3), (-16, 36), (-15, 34))
# Found off-region Cuboid((-19, -2), (-16, -11), (5, 24))
# Looking at off-regions added to Cuboid((-45, 0), (-9, 46), (-12, 38))
# Looking at off-regions added to Cuboid((-49, -3), (-44, 8), (-41, 12))
# Found off-region Cuboid((-45, -30), (-9, 4), (-30, -15))
# Found off-region Cuboid((-19, -3), (-21, -11), (5, 12))
# Found off-region Cuboid((-46, -27), (-44, -35), (-41, -30))
# Found overlap with another off-region, adding 128 back to the counter
# Found off-region Cuboid((-31, -19), (-41, -31), (-38, -25))
# Looking at off-regions added to Cuboid((-38, 15), (-39, 9), (-42, 11))
# Found off-region Cuboid((-19, -2), (-21, -11), (5, 11))
# Found off-region Cuboid((-38, -27), (-39, -35), (-42, -30))
# Found overlap with another off-region, adding 128 back to the counter
# Found off-region Cuboid((-31, -19), (-39, -31), (-38, -25))
# Looking at off-regions added to Cuboid((-34, -30), (-9, 4), (-30, -15))
# Looking at off-regions added to Cuboid((-34, -30), (-3, 4), (-30, -15))
# Looking at off-regions added to Cuboid((-38, -30), (-9, 4), (-30, -15))
# Looking at off-regions added to Cuboid((-35, 14), (-34, 17), (-25, 30))
# Looking at off-regions added to Cuboid((-34, -30), (-9, 4), (-25, -15))
# Looking at off-regions added to Cuboid((-19, -2), (-21, -11), (5, 8))
# Looking at off-regions added to Cuboid((-19, -2), (-21, -11), (5, 24))
# Looking at off-regions added to Cuboid((-34, -30), (-3, 4), (-25, -15))
# Looking at off-regions added to Cuboid((-19, -2), (-21, -11), (5, 24))
# Looking at off-regions added to Cuboid((-19, -2), (-15, -11), (5, 24))
# Looking at off-regions added to Cuboid((-19, -2), (-16, -11), (5, 24))
# Looking at off-regions added to Cuboid((-35, -30), (-9, 4), (-25, -15))
# Looking at off-regions added to Cuboid((-19, -3), (-21, -11), (5, 12))
# Looking at off-regions added to Cuboid((-19, -2), (-21, -11), (5, 11))
# Looking at off-regions added to Cuboid((-19, 29), (-47, 0), (-35, 13))
# Found off-region Cuboid((19, 29), (-22, -6), (-30, -10))
# Looking at off-regions added to Cuboid((-19, -2), (-21, -11), (5, 8))
# Looking at off-regions added to Cuboid((-19, -2), (-21, -11), (5, 13))
# Looking at off-regions added to Cuboid((-19, -2), (-21, -11), (5, 13))
# Looking at off-regions added to Cuboid((-19, -2), (-15, -11), (5, 13))
# Looking at off-regions added to Cuboid((-19, -2), (-16, -11), (5, 13))
# Looking at off-regions added to Cuboid((-19, -3), (-21, -11), (5, 12))
# Looking at off-regions added to Cuboid((-19, -2), (-21, -11), (5, 11))
# Looking at off-regions added to Cuboid((-13, 37), (-9, 42), (-12, 37))
# Looking at off-regions added to Cuboid((19, 32), (-9, -6), (-12, -10))
# Looking at off-regions added to Cuboid((19, 20), (-9, -6), (-12, -10))
# Looking at off-regions added to Cuboid((19, 21), (-9, -6), (-12, -10))
# Looking at off-regions added to Cuboid((19, 20), (-9, -6), (-12, -10))
# Looking at off-regions added to Cuboid((19, 29), (-9, -6), (-12, -10))
#
# Cube counter: 3900584
# But should be 221040
# That's a difference of 3679544.0
#
# New on-region
# Cuboid((-31, 15), (-37, 10), (-45, 5))
# Adding 108100 to the counter
# Found overlap with another overlap, adding 5130 to counter
# Found overlap with another overlap, adding 9450 to counter
# Found overlap with another overlap, adding 16606 to counter
# Found overlap with another overlap, adding 12690 to counter
# Found overlap with another overlap, adding 15884 to counter
# Found overlap with another overlap, adding 35420 to counter
# Found overlap with another overlap, adding 3510 to counter
# Found overlap with another overlap, adding 11362 to counter
# Found overlap with another overlap, adding 25714 to counter
# Found overlap with another overlap, adding 13156 to counter
# Found overlap with another overlap, adding 630 to counter
# Found overlap with another overlap, adding 3876 to counter
# Found overlap with another overlap, adding 7140 to counter
# Found overlap with another overlap, adding 6720 to counter
# Found overlap with another overlap, adding 2652 to counter
# Found overlap with another overlap, adding 2250 to counter
# Found overlap with another overlap, adding 12996 to counter
# Found overlap with another overlap, adding 17100 to counter
# Found overlap with another overlap, adding 16150 to counter
# Found overlap with another overlap, adding 8892 to counter
# Found overlap with another overlap, adding 5100 to counter
# Found overlap with another overlap, adding 1404 to counter
# Found overlap with another overlap, adding 12274 to counter
# Found overlap with another overlap, adding 17680 to counter
# Found overlap with another overlap, adding 16640 to counter
# Found overlap with another overlap, adding 8840 to counter
# Found overlap with another overlap, adding 5304 to counter
# Found overlap with another overlap, adding 16150 to counter
# Found overlap with another overlap, adding 10013 to counter
# Found overlap with another overlap, adding 10013 to counter
# Found overlap with another overlap, adding 9367 to counter
# Found overlap with another overlap, adding 6851 to counter
# Found overlap with another overlap, adding 3534 to counter
# Found overlap with another overlap, adding 10013 to counter
# Found overlap with another overlap, adding 10013 to counter
# Found overlap with another overlap, adding 9044 to counter
# Found overlap with another overlap, adding 39732 to counter
# Found overlap with another overlap, adding 26910 to counter
# Found overlap with another overlap, adding 14168 to counter
# Found overlap with another overlap, adding 5544 to counter
# Found overlap with another overlap, adding 12236 to counter
# Found overlap with another overlap, adding 13440 to counter
# Found overlap with another overlap, adding 8092 to counter
# Found overlap with another overlap, adding 12420 to counter
# Found overlap with another overlap, adding 15732 to counter
# Found overlap with another overlap, adding 67252 to counter
# Found overlap with another overlap, adding 46552 to counter
# Found overlap with another overlap, adding 25944 to counter
# Found overlap with another overlap, adding 6936 to counter
# Found overlap with another overlap, adding 16416 to counter
# Found overlap with another overlap, adding 17000 to counter
# Found overlap with another overlap, adding 9486 to counter
# Found overlap with another overlap, adding 57960 to counter
# Found overlap with another overlap, adding 11088 to counter
# Found overlap with another overlap, adding 16245 to counter
# Found overlap with another overlap, adding 47250 to counter
# Found overlap with another overlap, adding 43516 to counter
# Found overlap with another overlap, adding 17550 to counter
# Found overlap with another overlap, adding 7140 to counter
# Found overlap with another overlap, adding 17100 to counter
# Found overlap with another overlap, adding 17680 to counter
# Found overlap with another overlap, adding 10013 to counter
# Found overlap with another overlap, adding 35280 to counter
# Found overlap with another overlap, adding 58050 to counter
# Found overlap with another overlap, adding 130 to counter
# Found overlap with another overlap, adding 70 to counter
# Found overlap with another overlap, adding 130 to counter
# Found overlap with another overlap, adding 9990 to counter
# Found overlap with another overlap, adding 5814 to counter
# Found overlap with another overlap, adding 34000 to counter
# Found overlap with another overlap, adding 28934 to counter
# Found overlap with another overlap, adding 4080 to counter
# Found overlap with another overlap, adding 3300 to counter
# Found overlap with another overlap, adding 6840 to counter
# Found overlap with another overlap, adding 7040 to counter
# Found overlap with another overlap, adding 2907 to counter
# Found overlap with another overlap, adding 23680 to counter
# Found overlap with another overlap, adding 50320 to counter
# Found overlap with another overlap, adding 33660 to counter
# Found overlap with another overlap, adding 4845 to counter
# Found overlap with another overlap, adding 9044 to counter
# Found overlap with another overlap, adding 9044 to counter
# Found overlap with another overlap, adding 9044 to counter
# Found overlap with another overlap, adding 6188 to counter
# Found overlap with another overlap, adding 1824 to counter
# Found overlap with another overlap, adding 5814 to counter
# Found overlap with another overlap, adding 5168 to counter
# Found overlap with another overlap, adding 4199 to counter
# Found overlap with another overlap, adding 2890 to counter
# Found overlap with another overlap, adding 8568 to counter
# Found overlap with another overlap, adding 8721 to counter
# Found overlap with another overlap, adding 4284 to counter
# Found overlap with another on-cube, subtracting 12690 from the counter
# Found overlap with another on-cube, subtracting 16606 from the counter
# Found overlap with another on-cube, subtracting 69230 from the counter
# Found overlap with an off-region, adding 195 back to the counter
# And creating new cuboid Cuboid((-31, -30), (-9, 4), (-30, -15))
# Found overlap with another on-cube, subtracting 47564 from the counter
# Found overlap with another on-cube, subtracting 29900 from the counter
# Found overlap with an off-region, adding 105 back to the counter
# And creating new cuboid Cuboid((-31, -30), (-3, 4), (-30, -15))
# Found overlap with another on-cube, subtracting 7140 from the counter
# Found overlap with another on-cube, subtracting 17100 from the counter
# Found overlap with another on-cube, subtracting 17680 from the counter
# Found overlap with another on-cube, subtracting 10013 from the counter
# Found overlap with another on-cube, subtracting 57960 from the counter
# Found overlap with an off-region, adding 195 back to the counter
# And creating new cuboid Cuboid((-31, -30), (-9, 4), (-30, -15))
# Found overlap with an off-region, adding 88 back to the counter
# And creating new cuboid Cuboid((-31, -27), (-37, -35), (-41, -30))
# Found overlap with an off-region, adding 936 back to the counter
# And creating new cuboid Cuboid((-31, -19), (-37, -31), (-38, -25))
# Found overlap with another on-cube, subtracting 99452 from the counter
# Found overlap with an off-region, adding 96 back to the counter
# And creating new cuboid Cuboid((-31, -27), (-37, -35), (-42, -30))
# Found overlap with an off-region, adding 936 back to the counter
# And creating new cuboid Cuboid((-31, -19), (-37, -31), (-38, -25))
# Found overlap with another on-cube, subtracting 195 from the counter
# Found overlap with another on-cube, subtracting 105 from the counter
# Found overlap with another on-cube, subtracting 195 from the counter
# Found overlap with another on-cube, subtracting 59400 from the counter
# Found overlap with another on-cube, subtracting 130 from the counter
# Found overlap with another on-cube, subtracting 70 from the counter
# Found overlap with another on-cube, subtracting 130 from the counter
# Found overlap with another on-cube, subtracting 50320 from the counter
# Found overlap with another on-cube, subtracting 9044 from the counter
#
# Cube counter: 4853139
# But should be 596989
# That's a difference of 4256150.0

# %%
7669371029

# %%
988224.0
# Out:
# 988224.0

# %%
counter
# Out:
# 4853139
