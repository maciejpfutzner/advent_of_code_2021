# %%
from io import StringIO
from functools import reduce

# %%
data = '...'
data
# Out:
# '...'

# %%
example1 = 'D2FE28'
example2 = '38006F45291200'

# %% [markdown]
# # Part 1

# %%
def hex_to_bin(data):
    data_bin = ''.join([f'{int(d, base=16):04b}' for d in data])
    return data_bin

# %%
def read_literal(stream):
    read_counter = 0
    finished = False
    digits = ''
    while not finished:
        chunk = stream.read(5)
        read_counter += 5
        
        if chunk[0] == '0':
            finished = True
        digits += chunk[1:]
        #print(digits)
    value = int(digits, base=2)
    return value, read_counter

# %%
def read_op(pid, stream, versions):
    print('operator', pid)
    indicator = stream.read(1)
    read_counter = 1
    
    vals = []
    if indicator == '0':
        length = int(stream.read(15), base=2)
        read_counter += 15
        print(f'{length=}')
        
        sub_length = 0
        while sub_length < length:
            val, n = read_packet(stream, versions)
            sub_length += n
            vals.append(val)
        read_counter += sub_length
        
    else:
        number = int(stream.read(11), base=2)
        read_counter += 11
        print(f'{number=}')
        for i in range(number):
            val, n = read_packet(stream, versions)
            read_counter += n
            vals.append(val)
            
    # apply operation
    value = op_map[pid](vals)
    #print(f'operation {pid} on values {vals} gives {value}')
        
    return value, read_counter

# %%
def read_packet(stream, versions):
    version = int(stream.read(3), base=2)
    pid = int(stream.read(3), base=2)
    read_counter = 6
    print(f'{version=}')
    versions.append(version)
    
    if pid == 4:
        # literal value
        value, count = read_literal(stream)
        read_counter += count
    else:
        # operator
        value, count = read_op(pid, stream, versions)
        read_counter += count
        
    print(f'{value=}')
    return value, read_counter

# %%
def decode(data):
    versions = []
    stream = StringIO(hex_to_bin(data))
    return read_packet(stream, versions), versions

# %%
decode(example1)
# Out:
# version=6
# literal value: 2021
# ((21, 6, 4), [6])

# %%
decode('38006F45291200')
# Out:
# version=1
# operator
# length=27
# version=6
# literal value: 10
# version=2
# literal value: 20
# ((49, 1, 6), [1, 6, 2])

# %%
decode('EE00D40C823060')
# Out:
# version=7
# operator
# number=3
# version=2
# literal value: 1
# version=4
# literal value: 2
# version=1
# literal value: 3
# ((51, 7, 3), [7, 2, 4, 1])

# %%
decode('8A004A801A8002F478')
# Out:
# version=4
# operator
# number=1
# version=1
# operator
# number=1
# version=5
# operator
# length=11
# version=6
# literal value: 15
# ((69, 4, 2), [4, 1, 5, 6])

# %%
decode('620080001611562C8802118E34')
# Out:
# version=3
# operator
# number=2
# version=0
# operator
# length=22
# version=0
# literal value: 10
# version=5
# literal value: 11
# version=1
# operator
# number=2
# version=0
# literal value: 12
# version=3
# literal value: 13
# ((102, 3, 0), [3, 0, 0, 5, 1, 0, 3])

# %%
returns, versions = decode(data)
# Out:
# version=0
# operator
# length=5305
# version=1
# operator
# length=144
# version=2
# literal value: 784
# version=4
# literal value: 30800350288
# version=6
# literal value: 45345613
# version=0
# literal value: 197011
# version=3
# operator
# number=2
# version=6
# literal value: 226
# version=7
# literal value: 3148
# version=5
# operator
# number=3
# version=4
# literal value: 771208285333
# version=4
# literal value: 9
# version=1
# literal value: 13
# version=1
# literal value: 6342918
# version=4
# literal value: 8
# version=4
# operator
# length=81
# version=0
# operator
# number=2
# version=7
# literal value: 121
# version=4
# literal value: 15
# version=5
# literal value: 8881319
# version=1
# operator
# number=2
# version=7
# literal value: 88
# version=1
# literal value: 38665064
# version=3
# operator
# number=2
# version=7
# operator
# length=42
# version=7
# literal value: 327
# version=2
# literal value: 327
# version=1
# literal value: 842180
# version=6
# operator
# length=104
# version=4
# literal value: 2745
# version=6
# literal value: 10
# version=6
# literal value: 10237943
# version=0
# literal value: 14341013
# version=2
# operator
# length=85
# version=3
# literal value: 6
# version=1
# literal value: 3259
# version=7
# literal value: 42504
# version=6
# literal value: 5
# version=3
# literal value: 155
# version=6
# operator
# length=85
# version=5
# literal value: 255
# version=7
# operator
# length=47
# version=1
# literal value: 52353
# version=0
# literal value: 1964
# version=6
# operator
# length=59
# version=0
# literal value: 166
# version=3
# literal value: 118
# version=6
# literal value: 7
# version=7
# literal value: 221
# version=5
# operator
# length=90
# version=1
# operator
# length=52
# version=4
# literal value: 3645
# version=5
# literal value: 730081
# version=6
# literal value: 240
# version=2
# operator
# number=2
# version=3
# literal value: 1142
# version=3
# operator
# length=32
# version=3
# literal value: 114
# version=7
# literal value: 114
# version=7
# operator
# length=43
# version=7
# literal value: 98
# version=3
# literal value: 63
# version=3
# literal value: 3
# version=7
# literal value: 436
# version=7
# literal value: 7
# version=1
# operator
# length=416
# version=0
# operator
# number=1
# version=2
# operator
# number=1
# version=3
# operator
# number=1
# version=2
# operator
# length=340
# version=3
# operator
# number=1
# version=7
# operator
# length=300
# version=4
# operator
# length=278
# version=6
# operator
# length=256
# version=4
# operator
# length=234
# version=7
# operator
# length=212
# version=3
# operator
# number=1
# version=5
# operator
# length=172
# version=6
# operator
# number=1
# version=5
# operator
# length=132
# version=7
# operator
# number=1
# version=2
# operator
# length=92
# version=1
# operator
# length=70
# version=5
# operator
# length=48
# version=2
# operator
# length=26
# version=5
# literal value: 49075
# version=5
# operator
# number=5
# version=6
# literal value: 14
# version=0
# literal value: 37991
# version=6
# literal value: 21560
# version=6
# literal value: 32670
# version=1
# literal value: 17446113366716
# version=5
# operator
# length=140
# version=6
# literal value: 23288
# version=7
# operator
# length=92
# version=6
# literal value: 2388882143
# version=4
# literal value: 3759521228
# version=3
# operator
# number=2
# version=3
# operator
# number=2
# version=4
# literal value: 222
# version=4
# literal value: 32943
# version=7
# literal value: 32490
# version=2
# operator
# length=81
# version=0
# operator
# number=2
# version=3
# literal value: 896395
# version=7
# literal value: 93
# version=5
# literal value: 152
# version=2
# operator
# length=120
# version=2
# operator
# length=67
# version=7
# literal value: 2191
# version=3
# literal value: 1554461036
# version=5
# literal value: 650725
# version=0
# operator
# length=11
# version=6
# literal value: 11
# version=0
# operator
# number=3
# version=6
# literal value: 3306221
# version=0
# literal value: 1499
# version=1
# literal value: 2961
# version=6
# literal value: 116
# version=7
# operator
# length=75
# version=2
# operator
# length=37
# version=4
# literal value: 1442
# version=2
# literal value: 176
# version=7
# literal value: 217
# version=6
# operator
# length=153
# version=5
# operator
# number=3
# version=0
# literal value: 14
# version=5
# literal value: 13
# version=4
# literal value: 8
# version=1
# operator
# number=3
# version=4
# literal value: 6
# version=2
# literal value: 15
# version=3
# literal value: 8
# version=3
# operator
# number=3
# version=4
# literal value: 2
# version=6
# literal value: 13
# version=4
# literal value: 10
# version=1
# operator
# number=2
# version=4
# literal value: 124
# version=6
# operator
# number=2
# version=6
# literal value: 386
# version=4
# literal value: 45581
# version=7
# operator
# number=3
# version=5
# literal value: 3
# version=1
# literal value: 33088
# version=0
# literal value: 118
# version=4
# operator
# length=140
# version=4
# literal value: 245
# version=4
# operator
# number=2
# version=4
# operator
# number=3
# version=0
# literal value: 3
# version=6
# literal value: 10
# version=1
# literal value: 7
# version=0
# operator
# length=33
# version=5
# literal value: 11
# version=0
# literal value: 15
# version=1
# literal value: 11
# version=7
# operator
# number=2
# version=4
# operator
# length=106
# version=7
# operator
# number=3
# version=4
# literal value: 8
# version=5
# literal value: 13
# version=0
# literal value: 6
# version=4
# operator
# length=33
# version=4
# literal value: 15
# version=5
# literal value: 9
# version=0
# literal value: 7
# version=1
# literal value: 1297491
# version=3
# operator
# length=148
# version=0
# literal value: 157
# version=6
# operator
# length=110
# version=5
# operator
# length=33
# version=1
# literal value: 15
# version=3
# literal value: 9
# version=2
# literal value: 12
# version=6
# operator
# length=33
# version=1
# literal value: 13
# version=4
# literal value: 13
# version=3
# literal value: 8
# version=3
# operator
# length=101
# version=4
# literal value: 161789251
# version=2
# operator
# number=2
# version=0
# literal value: 2106
# version=4
# literal value: 2106
# version=6
# literal value: 1
# version=5
# operator
# length=32
# version=0
# literal value: 157
# version=2
# literal value: 128
# version=6
# operator
# number=3
# version=1
# operator
# number=3
# version=4
# literal value: 15
# version=3
# literal value: 15
# version=3
# literal value: 14
# version=0
# operator
# length=33
# version=1
# literal value: 8
# version=0
# literal value: 6
# version=5
# literal value: 7
# version=3
# operator
# length=33
# version=0
# literal value: 13
# version=4
# literal value: 10
# version=0
# literal value: 13
# version=0
# operator
# length=114
# version=4
# literal value: 169
# version=4
# literal value: 639450058
# version=1
# literal value: 723081
# version=7
# literal value: 2728
# version=6
# operator
# length=80
# version=5
# literal value: 133
# version=0
# operator
# length=42
# version=0
# literal value: 1561
# version=1
# literal value: 1561
# version=5
# literal value: 1539
# version=7
# literal value: 60795
# version=5
# operator
# number=2
# version=1
# literal value: 160
# version=3
# operator
# number=2
# version=5
# operator
# length=33
# version=3
# literal value: 12
# version=6
# literal value: 6
# version=6
# literal value: 3
# version=0
# operator
# number=3
# version=3
# literal value: 5
# version=2
# literal value: 15
# version=5
# literal value: 7
# version=6
# operator
# number=2
# version=1
# operator
# length=67
# version=1
# literal value: 12484780
# version=1
# literal value: 384035
# version=6
# literal value: 624
# version=4
# operator
# length=52
# version=6
# literal value: 7401045
# version=6
# literal value: 237
# version=3
# literal value: 4
# version=0
# operator
# number=5
# version=7
# literal value: 49650
# version=1
# literal value: 32367
# version=1
# literal value: 8902172
# version=0
# literal value: 593
# version=6
# literal value: 7182290
# version=6
# literal value: 20093
# version=5
# operator
# length=80
# version=3
# literal value: 117
# version=7
# literal value: 125
# version=7
# literal value: 224
# version=5
# literal value: 36
# version=7
# literal value: 142
# version=0
# operator
# number=2
# version=5
# operator
# length=32
# version=1
# literal value: 25
# version=6
# literal value: 25
# version=5
# literal value: 162
# version=6
# operator
# length=31
# version=5
# literal value: 162525
# version=6
# operator
# length=16
# version=0
# literal value: 138
# version=7
# operator
# length=31
# version=3
# literal value: 170455
# version=5
# operator
# length=141
# version=2
# literal value: 3462
# version=6
# operator
# number=2
# version=4
# operator
# number=3
# version=7
# literal value: 8
# version=1
# literal value: 11
# version=6
# literal value: 7
# version=5
# operator
# number=3
# version=6
# literal value: 6
# version=1
# literal value: 14
# version=5
# literal value: 6

# %% [markdown]
# # Part 2

# %%
op_map = {
    0: sum,
    1: lambda x: reduce(int.__mul__, x),
    2: min,
    3: max,
    5: lambda x: int(x[0] > x[1]),
    6: lambda x: int(x[0] < x[1]),
    7: lambda x: int(x[0] == x[1]),
}

# %%
code = 1
op_map[code]((6,9))
# Out:
# 54

# %%
(val, n), versions = decode('C200B40A82')
print('final value', val)
# Out:
# version=6
# operator 0
# number=2
# version=6
# value=1
# version=2
# value=2
# operation 0 on values [1, 2] gives 3
# value=3
# final value 3

# %%
(val, n), versions = decode('04005AC33890')
print('final value', val)
# Out:
# version=0
# operator 1
# length=22
# version=5
# value=6
# version=3
# value=9
# operation 1 on values [6, 9] gives 54
# value=54
# final value 54

# %%
(val, n), versions = decode('04005AC33890')
print('final value', val)
# Out:
# version=0
# operator 1
# length=22
# version=5
# value=6
# version=3
# value=9
# operation 1 on values [6, 9] gives 54
# value=54
# final value 54

# %%
(val, n), versions = decode('9C0141080250320F1802104A08')
print('final value', val)
# Out:
# version=4
# operator 7
# length=80
# version=2
# operator 0
# number=2
# version=2
# value=1
# version=4
# value=3
# value=4
# version=6
# operator 1
# number=2
# version=0
# value=2
# version=2
# value=2
# value=4
# value=1
# final value 1

# %%
(val, n), versions = decode(data)
print('final value', val)
# Out:
# version=0
# operator 0
# length=5305
# version=1
# operator 2
# length=144
# version=2
# value=784
# version=4
# value=30800350288
# version=6
# value=45345613
# version=0
# value=197011
# value=784
# version=3
# operator 0
# number=2
# version=6
# value=226
# version=7
# value=3148
# value=3374
# version=5
# operator 0
# number=3
# version=4
# value=771208285333
# version=4
# value=9
# version=1
# value=13
# value=771208285355
# version=1
# value=6342918
# version=4
# value=8
# version=4
# operator 1
# length=81
# version=0
# operator 6
# number=2
# version=7
# value=121
# version=4
# value=15
# value=0
# version=5
# value=8881319
# value=0
# version=1
# operator 3
# number=2
# version=7
# value=88
# version=1
# value=38665064
# value=38665064
# version=3
# operator 1
# number=2
# version=7
# operator 5
# length=42
# version=7
# value=327
# version=2
# value=327
# value=0
# version=1
# value=842180
# value=0
# version=6
# operator 3
# length=104
# version=4
# value=2745
# version=6
# value=10
# version=6
# value=10237943
# version=0
# value=14341013
# value=14341013
# version=2
# operator 2
# length=85
# version=3
# value=6
# version=1
# value=3259
# version=7
# value=42504
# version=6
# value=5
# version=3
# value=155
# value=5
# version=6
# operator 1
# length=85
# version=5
# value=255
# version=7
# operator 7
# length=47
# version=1
# value=52353
# version=0
# value=1964
# value=0
# value=0
# version=6
# operator 1
# length=59
# version=0
# value=166
# version=3
# value=118
# version=6
# value=7
# version=7
# value=221
# value=30302636
# version=5
# operator 1
# length=90
# version=1
# operator 6
# length=52
# version=4
# value=3645
# version=5
# value=730081
# value=1
# version=6
# value=240
# value=240
# version=2
# operator 1
# number=2
# version=3
# value=1142
# version=3
# operator 7
# length=32
# version=3
# value=114
# version=7
# value=114
# value=1
# value=1142
# version=7
# operator 1
# length=43
# version=7
# value=98
# version=3
# value=63
# version=3
# value=3
# value=18522
# version=7
# value=436
# version=7
# value=7
# version=1
# operator 1
# length=416
# version=0
# operator 1
# number=1
# version=2
# operator 2
# number=1
# version=3
# operator 0
# number=1
# version=2
# operator 0
# length=340
# version=3
# operator 1
# number=1
# version=7
# operator 3
# length=300
# version=4
# operator 2
# length=278
# version=6
# operator 3
# length=256
# version=4
# operator 0
# length=234
# version=7
# operator 3
# length=212
# version=3
# operator 1
# number=1
# version=5
# operator 1
# length=172
# version=6
# operator 0
# number=1
# version=5
# operator 2
# length=132
# version=7
# operator 0
# number=1
# version=2
# operator 0
# length=92
# version=1
# operator 2
# length=70
# version=5
# operator 2
# length=48
# version=2
# operator 0
# length=26
# version=5
# value=49075
# value=49075
# value=49075
# value=49075
# value=49075
# value=49075
# value=49075
# value=49075
# value=49075
# value=49075
# value=49075
# value=49075
# value=49075
# value=49075
# value=49075
# value=49075
# value=49075
# value=49075
# value=49075
# value=49075
# value=49075
# version=5
# operator 3
# number=5
# version=6
# value=14
# version=0
# value=37991
# version=6
# value=21560
# version=6
# value=32670
# version=1
# value=17446113366716
# value=17446113366716
# version=5
# operator 1
# length=140
# version=6
# value=23288
# version=7
# operator 5
# length=92
# version=6
# value=2388882143
# version=4
# value=3759521228
# value=0
# value=0
# version=3
# operator 1
# number=2
# version=3
# operator 6
# number=2
# version=4
# value=222
# version=4
# value=32943
# value=1
# version=7
# value=32490
# value=32490
# version=2
# operator 1
# length=81
# version=0
# operator 5
# number=2
# version=3
# value=896395
# version=7
# value=93
# value=1
# version=5
# value=152
# value=152
# version=2
# operator 1
# length=120
# version=2
# operator 7
# length=67
# version=7
# value=2191
# version=3
# value=1554461036
# value=0
# version=5
# value=650725
# value=0
# version=0
# operator 0
# length=11
# version=6
# value=11
# value=11
# version=0
# operator 2
# number=3
# version=6
# value=3306221
# version=0
# value=1499
# version=1
# value=2961
# value=1499
# version=6
# value=116
# version=7
# operator 1
# length=75
# version=2
# operator 5
# length=37
# version=4
# value=1442
# version=2
# value=176
# value=1
# version=7
# value=217
# value=217
# version=6
# operator 0
# length=153
# version=5
# operator 1
# number=3
# version=0
# value=14
# version=5
# value=13
# version=4
# value=8
# value=1456
# version=1
# operator 1
# number=3
# version=4
# value=6
# version=2
# value=15
# version=3
# value=8
# value=720
# version=3
# operator 1
# number=3
# version=4
# value=2
# version=6
# value=13
# version=4
# value=10
# value=260
# value=2436
# version=1
# operator 1
# number=2
# version=4
# value=124
# version=6
# operator 5
# number=2
# version=6
# value=386
# version=4
# value=45581
# value=0
# value=0
# version=7
# operator 3
# number=3
# version=5
# value=3
# version=1
# value=33088
# version=0
# value=118
# value=33088
# version=4
# operator 1
# length=140
# version=4
# value=245
# version=4
# operator 6
# number=2
# version=4
# operator 0
# number=3
# version=0
# value=3
# version=6
# value=10
# version=1
# value=7
# value=20
# version=0
# operator 0
# length=33
# version=5
# value=11
# version=0
# value=15
# version=1
# value=11
# value=37
# value=1
# value=245
# version=7
# operator 1
# number=2
# version=4
# operator 6
# length=106
# version=7
# operator 0
# number=3
# version=4
# value=8
# version=5
# value=13
# version=0
# value=6
# value=27
# version=4
# operator 0
# length=33
# version=4
# value=15
# version=5
# value=9
# version=0
# value=7
# value=31
# value=1
# version=1
# value=1297491
# value=1297491
# version=3
# operator 1
# length=148
# version=0
# value=157
# version=6
# operator 5
# length=110
# version=5
# operator 0
# length=33
# version=1
# value=15
# version=3
# value=9
# version=2
# value=12
# value=36
# version=6
# operator 0
# length=33
# version=1
# value=13
# version=4
# value=13
# version=3
# value=8
# value=34
# value=1
# value=157
# version=3
# operator 1
# length=101
# version=4
# value=161789251
# version=2
# operator 6
# number=2
# version=0
# value=2106
# version=4
# value=2106
# value=0
# value=0
# version=6
# value=1
# version=5
# operator 1
# length=32
# version=0
# value=157
# version=2
# value=128
# value=20096
# version=6
# operator 1
# number=3
# version=1
# operator 0
# number=3
# version=4
# value=15
# version=3
# value=15
# version=3
# value=14
# value=44
# version=0
# operator 0
# length=33
# version=1
# value=8
# version=0
# value=6
# version=5
# value=7
# value=21
# version=3
# operator 0
# length=33
# version=0
# value=13
# version=4
# value=10
# version=0
# value=13
# value=36
# value=33264
# version=0
# operator 0
# length=114
# version=4
# value=169
# version=4
# value=639450058
# version=1
# value=723081
# version=7
# value=2728
# value=640176036
# version=6
# operator 1
# length=80
# version=5
# value=133
# version=0
# operator 5
# length=42
# version=0
# value=1561
# version=1
# value=1561
# value=0
# value=0
# version=5
# value=1539
# version=7
# value=60795
# version=5
# operator 1
# number=2
# version=1
# value=160
# version=3
# operator 7
# number=2
# version=5
# operator 0
# length=33
# version=3
# value=12
# version=6
# value=6
# version=6
# value=3
# value=21
# version=0
# operator 0
# number=3
# version=3
# value=5
# version=2
# value=15
# version=5
# value=7
# value=27
# value=0
# value=0
# version=6
# operator 1
# number=2
# version=1
# operator 6
# length=67
# version=1
# value=12484780
# version=1
# value=384035
# value=0
# version=6
# value=624
# value=0
# version=4
# operator 2
# length=52
# version=6
# value=7401045
# version=6
# value=237
# value=237
# version=3
# value=4
# version=0
# operator 0
# number=5
# version=7
# value=49650
# version=1
# value=32367
# version=1
# value=8902172
# version=0
# value=593
# version=6
# value=7182290
# value=16167072
# version=6
# value=20093
# version=5
# operator 1
# length=80
# version=3
# value=117
# version=7
# value=125
# version=7
# value=224
# version=5
# value=36
# version=7
# value=142
# value=16746912000
# version=0
# operator 1
# number=2
# version=5
# operator 6
# length=32
# version=1
# value=25
# version=6
# value=25
# value=0
# version=5
# value=162
# value=0
# version=6
# operator 3
# length=31
# version=5
# value=162525
# value=162525
# version=6
# operator 1
# length=16
# version=0
# value=138
# value=138
# version=7
# operator 2
# length=31
# version=3
# value=170455
# value=170455
# version=5
# operator 1
# length=141
# version=2
# value=3462
# version=6
# operator 5
# number=2
# version=4
# operator 0
# number=3
# version=7
# value=8
# version=1
# value=11
# version=6
# value=7
# value=26
# version=5
# operator 0
# number=3
# version=6
# value=6
# version=1
# value=14
# version=5
# value=6
# value=26
# value=0
# value=0
# value=18234816469452
# final value 18234816469452

# %%
val
# Out:
# 18234816469452
