# %%
def parse_program(program):
    return [l.strip() for l in program.split('\n')]

# %%
with open('day24_monad_program.txt') as infile:
    monad = parse_program(infile.read())

# %%
monad
# Out:
# ['inp w',
#  'mul x 0',
#  'add x z',
#  'mod x 26',
#  'div z 1',
#  'add x 12',
#  'eql x w',
#  'eql x 0',
#  'mul y 0',
#  'add y 25',
#  'mul y x',
#  'add y 1',
#  'mul z y',
#  'mul y 0',
#  'add y w',
#  'add y 15',
#  'mul y x',
#  'add z y',
#  'inp w',
#  'mul x 0',
#  'add x z',
#  'mod x 26',
#  'div z 1',
#  'add x 14',
#  'eql x w',
#  'eql x 0',
#  'mul y 0',
#  'add y 25',
#  'mul y x',
#  'add y 1',
#  'mul z y',
#  'mul y 0',
#  'add y w',
#  'add y 12',
#  'mul y x',
#  'add z y',
#  'inp w',
#  'mul x 0',
#  'add x z',
#  'mod x 26',
#  'div z 1',
#  'add x 11',
#  'eql x w',
#  'eql x 0',
#  'mul y 0',
#  'add y 25',
#  'mul y x',
#  'add y 1',
#  'mul z y',
#  'mul y 0',
#  'add y w',
#  'add y 15',
#  'mul y x',
#  'add z y',
#  'inp w',
#  'mul x 0',
#  'add x z',
#  'mod x 26',
#  'div z 26',
#  'add x -9',
#  'eql x w',
#  'eql x 0',
#  'mul y 0',
#  'add y 25',
#  'mul y x',
#  'add y 1',
#  'mul z y',
#  'mul y 0',
#  'add y w',
#  'add y 12',
#  'mul y x',
#  'add z y',
#  'inp w',
#  'mul x 0',
#  'add x z',
#  'mod x 26',
#  'div z 26',
#  'add x -7',
#  'eql x w',
#  'eql x 0',
#  'mul y 0',
#  'add y 25',
#  'mul y x',
#  'add y 1',
#  'mul z y',
#  'mul y 0',
#  'add y w',
#  'add y 15',
#  'mul y x',
#  'add z y',
#  'inp w',
#  'mul x 0',
#  'add x z',
#  'mod x 26',
#  'div z 1',
#  'add x 11',
#  'eql x w',
#  'eql x 0',
#  'mul y 0',
#  'add y 25',
#  'mul y x',
#  'add y 1',
#  'mul z y',
#  'mul y 0',
#  'add y w',
#  'add y 2',
#  'mul y x',
#  'add z y',
#  'inp w',
#  'mul x 0',
#  'add x z',
#  'mod x 26',
#  'div z 26',
#  'add x -1',
#  'eql x w',
#  'eql x 0',
#  'mul y 0',
#  'add y 25',
#  'mul y x',
#  'add y 1',
#  'mul z y',
#  'mul y 0',
#  'add y w',
#  'add y 11',
#  'mul y x',
#  'add z y',
#  'inp w',
#  'mul x 0',
#  'add x z',
#  'mod x 26',
#  'div z 26',
#  'add x -16',
#  'eql x w',
#  'eql x 0',
#  'mul y 0',
#  'add y 25',
#  'mul y x',
#  'add y 1',
#  'mul z y',
#  'mul y 0',
#  'add y w',
#  'add y 15',
#  'mul y x',
#  'add z y',
#  'inp w',
#  'mul x 0',
#  'add x z',
#  'mod x 26',
#  'div z 1',
#  'add x 11',
#  'eql x w',
#  'eql x 0',
#  'mul y 0',
#  'add y 25',
#  'mul y x',
#  'add y 1',
#  'mul z y',
#  'mul y 0',
#  'add y w',
#  'add y 10',
#  'mul y x',
#  'add z y',
#  'inp w',
#  'mul x 0',
#  'add x z',
#  'mod x 26',
#  'div z 26',
#  'add x -15',
#  'eql x w',
#  'eql x 0',
#  'mul y 0',
#  'add y 25',
#  'mul y x',
#  'add y 1',
#  'mul z y',
#  'mul y 0',
#  'add y w',
#  'add y 2',
#  'mul y x',
#  'add z y',
#  'inp w',
#  'mul x 0',
#  'add x z',
#  'mod x 26',
#  'div z 1',
#  'add x 10',
#  'eql x w',
#  'eql x 0',
#  'mul y 0',
#  'add y 25',
#  'mul y x',
#  'add y 1',
#  'mul z y',
#  'mul y 0',
#  'add y w',
#  'add y 0',
#  'mul y x',
#  'add z y',
#  'inp w',
#  'mul x 0',
#  'add x z',
#  'mod x 26',
#  'div z 1',
#  'add x 12',
#  'eql x w',
#  'eql x 0',
#  'mul y 0',
#  'add y 25',
#  'mul y x',
#  'add y 1',
#  'mul z y',
#  'mul y 0',
#  'add y w',
#  'add y 0',
#  'mul y x',
#  'add z y',
#  'inp w',
#  'mul x 0',
#  'add x z',
#  'mod x 26',
#  'div z 26',
#  'add x -4',
#  'eql x w',
#  'eql x 0',
#  'mul y 0',
#  'add y 25',
#  'mul y x',
#  'add y 1',
#  'mul z y',
#  'mul y 0',
#  'add y w',
#  'add y 15',
#  'mul y x',
#  'add z y',
#  'inp w',
#  'mul x 0',
#  'add x z',
#  'mod x 26',
#  'div z 26',
#  'add x 0',
#  'eql x w',
#  'eql x 0',
#  'mul y 0',
#  'add y 25',
#  'mul y x',
#  'add y 1',
#  'mul z y',
#  'mul y 0',
#  'add y w',
#  'add y 15',
#  'mul y x',
#  'add z y']

# %% [markdown]
# # Part 1

# %%
def mock_input(num):
    num = str(num)
    if len(num) < 14:
        raise ValueError('Number too short')
    if '0' in num:
        raise ValueError('Number contains 0s')

    gen = (int(d) for d in num)
    def get_input():
        return next(gen)
    
    return get_input

# %%
class ALU():
    def __init__(self):
        self.reset()
    
    def reset(self):
        self.registers = dict(w=0, x=0, y=0, z=0)
        #self.verbose = False
        
    @staticmethod
    def get_instruction(line):
        op = line[:3]
        x = line[4]
        y = line[6:]
        return op, x, y
        
    def parse_operand(self, val):
        if val in 'wxyz':
            return self.registers[val]
        else:
            return int(val)
        
    def step(self, line):
        op, x, y = self.get_instruction(line)
        if op == 'inp':
            self.registers[x] = next(self.input_)
        elif op == 'add':
            self.registers[x] += self.parse_operand(y)
        elif op == 'mul':
            self.registers[x] *= self.parse_operand(y)
        elif op == 'div':
            self.registers[x] //= self.parse_operand(y)
        elif op == 'mod':
            self.registers[x] %= self.parse_operand(y)
        elif op == 'eql':
            self.registers[x] = int(self.registers[x] == self.parse_operand(y))
    
    def run(self, program, input_, verbose=False):
        self.reset()
        self.input_ = (int(i) for i in input_)
        for i, l in enumerate(program):
            self.step(l)
            if verbose:
                print(f'{i+1}: {l}')
                print(self.registers)
        return self.registers.copy()

# %%
alu = ALU()

# %%
binary = """\
inp w
add z w
mod z 2
div w 2
add y w
mod y 2
div w 2
add x w
mod x 2
div w 2
mod w 2"""

number = 4

program = parse_program(binary)
regs = alu.run(program, [number])

print(regs)
print(bin(number))
# Out:
# {'w': 0, 'x': 1, 'y': 0, 'z': 0}
# 0b100

# %%
prog2 = """\
inp z
inp x
mul z 3
eql z x"""
input2 = [2, 1]

alu.run(parse_program(prog2), input2)
# Out:
# {'w': 0, 'x': 1, 'y': 0, 'z': 0}

# %% [markdown]
# ### Now try the monad program

# %%
top_number = int('9'*14)
top_number
# Out:
# 99999999999999

# %%
alu.run(monad, str(top_number))
# Out:
# {'w': 9, 'x': 1, 'y': 24, 'z': 7674884462}

# %%
# %%timeit
alu.run(monad, str(top_number))
# Out:
# 253 µs ± 7.94 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %% [raw]
# After line 30: w=d2, x=1, y=26, z=d1+15
# After line 50: w=d3, x=1, y=0, z= ((d1+15)*26 + d2+12)*26
# After line 70, asumming d4=d3+6: w=d4, x=0, y=0, z=(d1+15)*26 + d2+12
# After line 90, same assumptions: w=d5, x=1, y=d5+15, z=(d1+15)*26 +d5+15
# After line 120, if d7 = d6+1: w=d7, x=0, y=1, z=(d1+15)*26 +d5+15
# After line 150: w=d9, x=d1+26, y=0, z=d1+15

# %% [markdown]
# Conditions:
# - d3, d4: d3 = d4-6, so best d3=3, d4=9
# - d1, d8: d8 = d1-1, so best d1=9, d8=8
# - d2, d5: d5 = d2+5, so best d2=4, d5=9
# - d6, d7: d7 = d6+1, so best d6=8, d7=9
# - d9, d10: d10 = d9-5, so best d9=9, d10=4
# - d11, d14: d11 == d14, so both = 9
# - d12, d13: d13 = d12-4, so best d13=9, d12=5

# %%
num = 12345678912345
num = 94399898949959
regs = alu.run(monad, str(num), verbose=True)
# Out:
# 1: inp w
# {'w': 9, 'x': 0, 'y': 0, 'z': 0}
# 2: mul x 0
# {'w': 9, 'x': 0, 'y': 0, 'z': 0}
# 3: add x z
# {'w': 9, 'x': 0, 'y': 0, 'z': 0}
# 4: mod x 26
# {'w': 9, 'x': 0, 'y': 0, 'z': 0}
# 5: div z 1
# {'w': 9, 'x': 0, 'y': 0, 'z': 0}
# 6: add x 12
# {'w': 9, 'x': 12, 'y': 0, 'z': 0}
# 7: eql x w
# {'w': 9, 'x': 0, 'y': 0, 'z': 0}
# 8: eql x 0
# {'w': 9, 'x': 1, 'y': 0, 'z': 0}
# 9: mul y 0
# {'w': 9, 'x': 1, 'y': 0, 'z': 0}
# 10: add y 25
# {'w': 9, 'x': 1, 'y': 25, 'z': 0}
# 11: mul y x
# {'w': 9, 'x': 1, 'y': 25, 'z': 0}
# 12: add y 1
# {'w': 9, 'x': 1, 'y': 26, 'z': 0}
# 13: mul z y
# {'w': 9, 'x': 1, 'y': 26, 'z': 0}
# 14: mul y 0
# {'w': 9, 'x': 1, 'y': 0, 'z': 0}
# 15: add y w
# {'w': 9, 'x': 1, 'y': 9, 'z': 0}
# 16: add y 15
# {'w': 9, 'x': 1, 'y': 24, 'z': 0}
# 17: mul y x
# {'w': 9, 'x': 1, 'y': 24, 'z': 0}
# 18: add z y
# {'w': 9, 'x': 1, 'y': 24, 'z': 24}
# 19: inp w
# {'w': 4, 'x': 1, 'y': 24, 'z': 24}
# 20: mul x 0
# {'w': 4, 'x': 0, 'y': 24, 'z': 24}
# 21: add x z
# {'w': 4, 'x': 24, 'y': 24, 'z': 24}
# 22: mod x 26
# {'w': 4, 'x': 24, 'y': 24, 'z': 24}
# 23: div z 1
# {'w': 4, 'x': 24, 'y': 24, 'z': 24}
# 24: add x 14
# {'w': 4, 'x': 38, 'y': 24, 'z': 24}
# 25: eql x w
# {'w': 4, 'x': 0, 'y': 24, 'z': 24}
# 26: eql x 0
# {'w': 4, 'x': 1, 'y': 24, 'z': 24}
# 27: mul y 0
# {'w': 4, 'x': 1, 'y': 0, 'z': 24}
# 28: add y 25
# {'w': 4, 'x': 1, 'y': 25, 'z': 24}
# 29: mul y x
# {'w': 4, 'x': 1, 'y': 25, 'z': 24}
# 30: add y 1
# {'w': 4, 'x': 1, 'y': 26, 'z': 24}
# 31: mul z y
# {'w': 4, 'x': 1, 'y': 26, 'z': 624}
# 32: mul y 0
# {'w': 4, 'x': 1, 'y': 0, 'z': 624}
# 33: add y w
# {'w': 4, 'x': 1, 'y': 4, 'z': 624}
# 34: add y 12
# {'w': 4, 'x': 1, 'y': 16, 'z': 624}
# 35: mul y x
# {'w': 4, 'x': 1, 'y': 16, 'z': 624}
# 36: add z y
# {'w': 4, 'x': 1, 'y': 16, 'z': 640}
# 37: inp w
# {'w': 3, 'x': 1, 'y': 16, 'z': 640}
# 38: mul x 0
# {'w': 3, 'x': 0, 'y': 16, 'z': 640}
# 39: add x z
# {'w': 3, 'x': 640, 'y': 16, 'z': 640}
# 40: mod x 26
# {'w': 3, 'x': 16, 'y': 16, 'z': 640}
# 41: div z 1
# {'w': 3, 'x': 16, 'y': 16, 'z': 640}
# 42: add x 11
# {'w': 3, 'x': 27, 'y': 16, 'z': 640}
# 43: eql x w
# {'w': 3, 'x': 0, 'y': 16, 'z': 640}
# 44: eql x 0
# {'w': 3, 'x': 1, 'y': 16, 'z': 640}
# 45: mul y 0
# {'w': 3, 'x': 1, 'y': 0, 'z': 640}
# 46: add y 25
# {'w': 3, 'x': 1, 'y': 25, 'z': 640}
# 47: mul y x
# {'w': 3, 'x': 1, 'y': 25, 'z': 640}
# 48: add y 1
# {'w': 3, 'x': 1, 'y': 26, 'z': 640}
# 49: mul z y
# {'w': 3, 'x': 1, 'y': 26, 'z': 16640}
# 50: mul y 0
# {'w': 3, 'x': 1, 'y': 0, 'z': 16640}
# 51: add y w
# {'w': 3, 'x': 1, 'y': 3, 'z': 16640}
# 52: add y 15
# {'w': 3, 'x': 1, 'y': 18, 'z': 16640}
# 53: mul y x
# {'w': 3, 'x': 1, 'y': 18, 'z': 16640}
# 54: add z y
# {'w': 3, 'x': 1, 'y': 18, 'z': 16658}
# 55: inp w
# {'w': 9, 'x': 1, 'y': 18, 'z': 16658}
# 56: mul x 0
# {'w': 9, 'x': 0, 'y': 18, 'z': 16658}
# 57: add x z
# {'w': 9, 'x': 16658, 'y': 18, 'z': 16658}
# 58: mod x 26
# {'w': 9, 'x': 18, 'y': 18, 'z': 16658}
# 59: div z 26
# {'w': 9, 'x': 18, 'y': 18, 'z': 640}
# 60: add x -9
# {'w': 9, 'x': 9, 'y': 18, 'z': 640}
# 61: eql x w
# {'w': 9, 'x': 1, 'y': 18, 'z': 640}
# 62: eql x 0
# {'w': 9, 'x': 0, 'y': 18, 'z': 640}
# 63: mul y 0
# {'w': 9, 'x': 0, 'y': 0, 'z': 640}
# 64: add y 25
# {'w': 9, 'x': 0, 'y': 25, 'z': 640}
# 65: mul y x
# {'w': 9, 'x': 0, 'y': 0, 'z': 640}
# 66: add y 1
# {'w': 9, 'x': 0, 'y': 1, 'z': 640}
# 67: mul z y
# {'w': 9, 'x': 0, 'y': 1, 'z': 640}
# 68: mul y 0
# {'w': 9, 'x': 0, 'y': 0, 'z': 640}
# 69: add y w
# {'w': 9, 'x': 0, 'y': 9, 'z': 640}
# 70: add y 12
# {'w': 9, 'x': 0, 'y': 21, 'z': 640}
# 71: mul y x
# {'w': 9, 'x': 0, 'y': 0, 'z': 640}
# 72: add z y
# {'w': 9, 'x': 0, 'y': 0, 'z': 640}
# 73: inp w
# {'w': 9, 'x': 0, 'y': 0, 'z': 640}
# 74: mul x 0
# {'w': 9, 'x': 0, 'y': 0, 'z': 640}
# 75: add x z
# {'w': 9, 'x': 640, 'y': 0, 'z': 640}
# 76: mod x 26
# {'w': 9, 'x': 16, 'y': 0, 'z': 640}
# 77: div z 26
# {'w': 9, 'x': 16, 'y': 0, 'z': 24}
# 78: add x -7
# {'w': 9, 'x': 9, 'y': 0, 'z': 24}
# 79: eql x w
# {'w': 9, 'x': 1, 'y': 0, 'z': 24}
# 80: eql x 0
# {'w': 9, 'x': 0, 'y': 0, 'z': 24}
# 81: mul y 0
# {'w': 9, 'x': 0, 'y': 0, 'z': 24}
# 82: add y 25
# {'w': 9, 'x': 0, 'y': 25, 'z': 24}
# 83: mul y x
# {'w': 9, 'x': 0, 'y': 0, 'z': 24}
# 84: add y 1
# {'w': 9, 'x': 0, 'y': 1, 'z': 24}
# 85: mul z y
# {'w': 9, 'x': 0, 'y': 1, 'z': 24}
# 86: mul y 0
# {'w': 9, 'x': 0, 'y': 0, 'z': 24}
# 87: add y w
# {'w': 9, 'x': 0, 'y': 9, 'z': 24}
# 88: add y 15
# {'w': 9, 'x': 0, 'y': 24, 'z': 24}
# 89: mul y x
# {'w': 9, 'x': 0, 'y': 0, 'z': 24}
# 90: add z y
# {'w': 9, 'x': 0, 'y': 0, 'z': 24}
# 91: inp w
# {'w': 8, 'x': 0, 'y': 0, 'z': 24}
# 92: mul x 0
# {'w': 8, 'x': 0, 'y': 0, 'z': 24}
# 93: add x z
# {'w': 8, 'x': 24, 'y': 0, 'z': 24}
# 94: mod x 26
# {'w': 8, 'x': 24, 'y': 0, 'z': 24}
# 95: div z 1
# {'w': 8, 'x': 24, 'y': 0, 'z': 24}
# 96: add x 11
# {'w': 8, 'x': 35, 'y': 0, 'z': 24}
# 97: eql x w
# {'w': 8, 'x': 0, 'y': 0, 'z': 24}
# 98: eql x 0
# {'w': 8, 'x': 1, 'y': 0, 'z': 24}
# 99: mul y 0
# {'w': 8, 'x': 1, 'y': 0, 'z': 24}
# 100: add y 25
# {'w': 8, 'x': 1, 'y': 25, 'z': 24}
# 101: mul y x
# {'w': 8, 'x': 1, 'y': 25, 'z': 24}
# 102: add y 1
# {'w': 8, 'x': 1, 'y': 26, 'z': 24}
# 103: mul z y
# {'w': 8, 'x': 1, 'y': 26, 'z': 624}
# 104: mul y 0
# {'w': 8, 'x': 1, 'y': 0, 'z': 624}
# 105: add y w
# {'w': 8, 'x': 1, 'y': 8, 'z': 624}
# 106: add y 2
# {'w': 8, 'x': 1, 'y': 10, 'z': 624}
# 107: mul y x
# {'w': 8, 'x': 1, 'y': 10, 'z': 624}
# 108: add z y
# {'w': 8, 'x': 1, 'y': 10, 'z': 634}
# 109: inp w
# {'w': 9, 'x': 1, 'y': 10, 'z': 634}
# 110: mul x 0
# {'w': 9, 'x': 0, 'y': 10, 'z': 634}
# 111: add x z
# {'w': 9, 'x': 634, 'y': 10, 'z': 634}
# 112: mod x 26
# {'w': 9, 'x': 10, 'y': 10, 'z': 634}
# 113: div z 26
# {'w': 9, 'x': 10, 'y': 10, 'z': 24}
# 114: add x -1
# {'w': 9, 'x': 9, 'y': 10, 'z': 24}
# 115: eql x w
# {'w': 9, 'x': 1, 'y': 10, 'z': 24}
# 116: eql x 0
# {'w': 9, 'x': 0, 'y': 10, 'z': 24}
# 117: mul y 0
# {'w': 9, 'x': 0, 'y': 0, 'z': 24}
# 118: add y 25
# {'w': 9, 'x': 0, 'y': 25, 'z': 24}
# 119: mul y x
# {'w': 9, 'x': 0, 'y': 0, 'z': 24}
# 120: add y 1
# {'w': 9, 'x': 0, 'y': 1, 'z': 24}
# 121: mul z y
# {'w': 9, 'x': 0, 'y': 1, 'z': 24}
# 122: mul y 0
# {'w': 9, 'x': 0, 'y': 0, 'z': 24}
# 123: add y w
# {'w': 9, 'x': 0, 'y': 9, 'z': 24}
# 124: add y 11
# {'w': 9, 'x': 0, 'y': 20, 'z': 24}
# 125: mul y x
# {'w': 9, 'x': 0, 'y': 0, 'z': 24}
# 126: add z y
# {'w': 9, 'x': 0, 'y': 0, 'z': 24}
# 127: inp w
# {'w': 8, 'x': 0, 'y': 0, 'z': 24}
# 128: mul x 0
# {'w': 8, 'x': 0, 'y': 0, 'z': 24}
# 129: add x z
# {'w': 8, 'x': 24, 'y': 0, 'z': 24}
# 130: mod x 26
# {'w': 8, 'x': 24, 'y': 0, 'z': 24}
# 131: div z 26
# {'w': 8, 'x': 24, 'y': 0, 'z': 0}
# 132: add x -16
# {'w': 8, 'x': 8, 'y': 0, 'z': 0}
# 133: eql x w
# {'w': 8, 'x': 1, 'y': 0, 'z': 0}
# 134: eql x 0
# {'w': 8, 'x': 0, 'y': 0, 'z': 0}
# 135: mul y 0
# {'w': 8, 'x': 0, 'y': 0, 'z': 0}
# 136: add y 25
# {'w': 8, 'x': 0, 'y': 25, 'z': 0}
# 137: mul y x
# {'w': 8, 'x': 0, 'y': 0, 'z': 0}
# 138: add y 1
# {'w': 8, 'x': 0, 'y': 1, 'z': 0}
# 139: mul z y
# {'w': 8, 'x': 0, 'y': 1, 'z': 0}
# 140: mul y 0
# {'w': 8, 'x': 0, 'y': 0, 'z': 0}
# 141: add y w
# {'w': 8, 'x': 0, 'y': 8, 'z': 0}
# 142: add y 15
# {'w': 8, 'x': 0, 'y': 23, 'z': 0}
# 143: mul y x
# {'w': 8, 'x': 0, 'y': 0, 'z': 0}
# 144: add z y
# {'w': 8, 'x': 0, 'y': 0, 'z': 0}
# 145: inp w
# {'w': 9, 'x': 0, 'y': 0, 'z': 0}
# 146: mul x 0
# {'w': 9, 'x': 0, 'y': 0, 'z': 0}
# 147: add x z
# {'w': 9, 'x': 0, 'y': 0, 'z': 0}
# 148: mod x 26
# {'w': 9, 'x': 0, 'y': 0, 'z': 0}
# 149: div z 1
# {'w': 9, 'x': 0, 'y': 0, 'z': 0}
# 150: add x 11
# {'w': 9, 'x': 11, 'y': 0, 'z': 0}
# 151: eql x w
# {'w': 9, 'x': 0, 'y': 0, 'z': 0}
# 152: eql x 0
# {'w': 9, 'x': 1, 'y': 0, 'z': 0}
# 153: mul y 0
# {'w': 9, 'x': 1, 'y': 0, 'z': 0}
# 154: add y 25
# {'w': 9, 'x': 1, 'y': 25, 'z': 0}
# 155: mul y x
# {'w': 9, 'x': 1, 'y': 25, 'z': 0}
# 156: add y 1
# {'w': 9, 'x': 1, 'y': 26, 'z': 0}
# 157: mul z y
# {'w': 9, 'x': 1, 'y': 26, 'z': 0}
# 158: mul y 0
# {'w': 9, 'x': 1, 'y': 0, 'z': 0}
# 159: add y w
# {'w': 9, 'x': 1, 'y': 9, 'z': 0}
# 160: add y 10
# {'w': 9, 'x': 1, 'y': 19, 'z': 0}
# 161: mul y x
# {'w': 9, 'x': 1, 'y': 19, 'z': 0}
# 162: add z y
# {'w': 9, 'x': 1, 'y': 19, 'z': 19}
# 163: inp w
# {'w': 4, 'x': 1, 'y': 19, 'z': 19}
# 164: mul x 0
# {'w': 4, 'x': 0, 'y': 19, 'z': 19}
# 165: add x z
# {'w': 4, 'x': 19, 'y': 19, 'z': 19}
# 166: mod x 26
# {'w': 4, 'x': 19, 'y': 19, 'z': 19}
# 167: div z 26
# {'w': 4, 'x': 19, 'y': 19, 'z': 0}
# 168: add x -15
# {'w': 4, 'x': 4, 'y': 19, 'z': 0}
# 169: eql x w
# {'w': 4, 'x': 1, 'y': 19, 'z': 0}
# 170: eql x 0
# {'w': 4, 'x': 0, 'y': 19, 'z': 0}
# 171: mul y 0
# {'w': 4, 'x': 0, 'y': 0, 'z': 0}
# 172: add y 25
# {'w': 4, 'x': 0, 'y': 25, 'z': 0}
# 173: mul y x
# {'w': 4, 'x': 0, 'y': 0, 'z': 0}
# 174: add y 1
# {'w': 4, 'x': 0, 'y': 1, 'z': 0}
# 175: mul z y
# {'w': 4, 'x': 0, 'y': 1, 'z': 0}
# 176: mul y 0
# {'w': 4, 'x': 0, 'y': 0, 'z': 0}
# 177: add y w
# {'w': 4, 'x': 0, 'y': 4, 'z': 0}
# 178: add y 2
# {'w': 4, 'x': 0, 'y': 6, 'z': 0}
# 179: mul y x
# {'w': 4, 'x': 0, 'y': 0, 'z': 0}
# 180: add z y
# {'w': 4, 'x': 0, 'y': 0, 'z': 0}
# 181: inp w
# {'w': 9, 'x': 0, 'y': 0, 'z': 0}
# 182: mul x 0
# {'w': 9, 'x': 0, 'y': 0, 'z': 0}
# 183: add x z
# {'w': 9, 'x': 0, 'y': 0, 'z': 0}
# 184: mod x 26
# {'w': 9, 'x': 0, 'y': 0, 'z': 0}
# 185: div z 1
# {'w': 9, 'x': 0, 'y': 0, 'z': 0}
# 186: add x 10
# {'w': 9, 'x': 10, 'y': 0, 'z': 0}
# 187: eql x w
# {'w': 9, 'x': 0, 'y': 0, 'z': 0}
# 188: eql x 0
# {'w': 9, 'x': 1, 'y': 0, 'z': 0}
# 189: mul y 0
# {'w': 9, 'x': 1, 'y': 0, 'z': 0}
# 190: add y 25
# {'w': 9, 'x': 1, 'y': 25, 'z': 0}
# 191: mul y x
# {'w': 9, 'x': 1, 'y': 25, 'z': 0}
# 192: add y 1
# {'w': 9, 'x': 1, 'y': 26, 'z': 0}
# 193: mul z y
# {'w': 9, 'x': 1, 'y': 26, 'z': 0}
# 194: mul y 0
# {'w': 9, 'x': 1, 'y': 0, 'z': 0}
# 195: add y w
# {'w': 9, 'x': 1, 'y': 9, 'z': 0}
# 196: add y 0
# {'w': 9, 'x': 1, 'y': 9, 'z': 0}
# 197: mul y x
# {'w': 9, 'x': 1, 'y': 9, 'z': 0}
# 198: add z y
# {'w': 9, 'x': 1, 'y': 9, 'z': 9}
# 199: inp w
# {'w': 9, 'x': 1, 'y': 9, 'z': 9}
# 200: mul x 0
# {'w': 9, 'x': 0, 'y': 9, 'z': 9}
# 201: add x z
# {'w': 9, 'x': 9, 'y': 9, 'z': 9}
# 202: mod x 26
# {'w': 9, 'x': 9, 'y': 9, 'z': 9}
# 203: div z 1
# {'w': 9, 'x': 9, 'y': 9, 'z': 9}
# 204: add x 12
# {'w': 9, 'x': 21, 'y': 9, 'z': 9}
# 205: eql x w
# {'w': 9, 'x': 0, 'y': 9, 'z': 9}
# 206: eql x 0
# {'w': 9, 'x': 1, 'y': 9, 'z': 9}
# 207: mul y 0
# {'w': 9, 'x': 1, 'y': 0, 'z': 9}
# 208: add y 25
# {'w': 9, 'x': 1, 'y': 25, 'z': 9}
# 209: mul y x
# {'w': 9, 'x': 1, 'y': 25, 'z': 9}
# 210: add y 1
# {'w': 9, 'x': 1, 'y': 26, 'z': 9}
# 211: mul z y
# {'w': 9, 'x': 1, 'y': 26, 'z': 234}
# 212: mul y 0
# {'w': 9, 'x': 1, 'y': 0, 'z': 234}
# 213: add y w
# {'w': 9, 'x': 1, 'y': 9, 'z': 234}
# 214: add y 0
# {'w': 9, 'x': 1, 'y': 9, 'z': 234}
# 215: mul y x
# {'w': 9, 'x': 1, 'y': 9, 'z': 234}
# 216: add z y
# {'w': 9, 'x': 1, 'y': 9, 'z': 243}
# 217: inp w
# {'w': 5, 'x': 1, 'y': 9, 'z': 243}
# 218: mul x 0
# {'w': 5, 'x': 0, 'y': 9, 'z': 243}
# 219: add x z
# {'w': 5, 'x': 243, 'y': 9, 'z': 243}
# 220: mod x 26
# {'w': 5, 'x': 9, 'y': 9, 'z': 243}
# 221: div z 26
# {'w': 5, 'x': 9, 'y': 9, 'z': 9}
# 222: add x -4
# {'w': 5, 'x': 5, 'y': 9, 'z': 9}
# 223: eql x w
# {'w': 5, 'x': 1, 'y': 9, 'z': 9}
# 224: eql x 0
# {'w': 5, 'x': 0, 'y': 9, 'z': 9}
# 225: mul y 0
# {'w': 5, 'x': 0, 'y': 0, 'z': 9}
# 226: add y 25
# {'w': 5, 'x': 0, 'y': 25, 'z': 9}
# 227: mul y x
# {'w': 5, 'x': 0, 'y': 0, 'z': 9}
# 228: add y 1
# {'w': 5, 'x': 0, 'y': 1, 'z': 9}
# 229: mul z y
# {'w': 5, 'x': 0, 'y': 1, 'z': 9}
# 230: mul y 0
# {'w': 5, 'x': 0, 'y': 0, 'z': 9}
# 231: add y w
# {'w': 5, 'x': 0, 'y': 5, 'z': 9}
# 232: add y 15
# {'w': 5, 'x': 0, 'y': 20, 'z': 9}
# 233: mul y x
# {'w': 5, 'x': 0, 'y': 0, 'z': 9}
# 234: add z y
# {'w': 5, 'x': 0, 'y': 0, 'z': 9}
# 235: inp w
# {'w': 9, 'x': 0, 'y': 0, 'z': 9}
# 236: mul x 0
# {'w': 9, 'x': 0, 'y': 0, 'z': 9}
# 237: add x z
# {'w': 9, 'x': 9, 'y': 0, 'z': 9}
# 238: mod x 26
# {'w': 9, 'x': 9, 'y': 0, 'z': 9}
# 239: div z 26
# {'w': 9, 'x': 9, 'y': 0, 'z': 0}
# 240: add x 0
# {'w': 9, 'x': 9, 'y': 0, 'z': 0}
# 241: eql x w
# {'w': 9, 'x': 1, 'y': 0, 'z': 0}
# 242: eql x 0
# {'w': 9, 'x': 0, 'y': 0, 'z': 0}
# 243: mul y 0
# {'w': 9, 'x': 0, 'y': 0, 'z': 0}
# 244: add y 25
# {'w': 9, 'x': 0, 'y': 25, 'z': 0}
# 245: mul y x
# {'w': 9, 'x': 0, 'y': 0, 'z': 0}
# 246: add y 1
# {'w': 9, 'x': 0, 'y': 1, 'z': 0}
# 247: mul z y
# {'w': 9, 'x': 0, 'y': 1, 'z': 0}
# 248: mul y 0
# {'w': 9, 'x': 0, 'y': 0, 'z': 0}
# 249: add y w
# {'w': 9, 'x': 0, 'y': 9, 'z': 0}
# 250: add y 15
# {'w': 9, 'x': 0, 'y': 24, 'z': 0}
# 251: mul y x
# {'w': 9, 'x': 0, 'y': 0, 'z': 0}
# 252: add z y
# {'w': 9, 'x': 0, 'y': 0, 'z': 0}

# %%
regs['z']
# Out:
# 0

# %% [markdown]
# # Part 2
#
# Conditions:
# - d1, d8: d1 = d8+1, so best d1=2, d8=1
# - d2, d5: d5 = d2+5, so best d2=1, d5=6
# - d3, d4: d4 = d3+6, so best d3=1, d4=7
# - d6, d7: d7 = d6+1, so best d6=1, d7=2
# - d9, d10: d9 = d10+5, so best d9=6, d10=1
# - d11, d14: d11 == d14, so both = 1
# - d12, d13: d12 = d13+4, so best d13=1, d12=5

# %%
num = 12345678901234
num = 21176121611511
regs = alu.run(monad, str(num), verbose=True)
# Out:
# 1: inp w
# {'w': 2, 'x': 0, 'y': 0, 'z': 0}
# 2: mul x 0
# {'w': 2, 'x': 0, 'y': 0, 'z': 0}
# 3: add x z
# {'w': 2, 'x': 0, 'y': 0, 'z': 0}
# 4: mod x 26
# {'w': 2, 'x': 0, 'y': 0, 'z': 0}
# 5: div z 1
# {'w': 2, 'x': 0, 'y': 0, 'z': 0}
# 6: add x 12
# {'w': 2, 'x': 12, 'y': 0, 'z': 0}
# 7: eql x w
# {'w': 2, 'x': 0, 'y': 0, 'z': 0}
# 8: eql x 0
# {'w': 2, 'x': 1, 'y': 0, 'z': 0}
# 9: mul y 0
# {'w': 2, 'x': 1, 'y': 0, 'z': 0}
# 10: add y 25
# {'w': 2, 'x': 1, 'y': 25, 'z': 0}
# 11: mul y x
# {'w': 2, 'x': 1, 'y': 25, 'z': 0}
# 12: add y 1
# {'w': 2, 'x': 1, 'y': 26, 'z': 0}
# 13: mul z y
# {'w': 2, 'x': 1, 'y': 26, 'z': 0}
# 14: mul y 0
# {'w': 2, 'x': 1, 'y': 0, 'z': 0}
# 15: add y w
# {'w': 2, 'x': 1, 'y': 2, 'z': 0}
# 16: add y 15
# {'w': 2, 'x': 1, 'y': 17, 'z': 0}
# 17: mul y x
# {'w': 2, 'x': 1, 'y': 17, 'z': 0}
# 18: add z y
# {'w': 2, 'x': 1, 'y': 17, 'z': 17}
# 19: inp w
# {'w': 1, 'x': 1, 'y': 17, 'z': 17}
# 20: mul x 0
# {'w': 1, 'x': 0, 'y': 17, 'z': 17}
# 21: add x z
# {'w': 1, 'x': 17, 'y': 17, 'z': 17}
# 22: mod x 26
# {'w': 1, 'x': 17, 'y': 17, 'z': 17}
# 23: div z 1
# {'w': 1, 'x': 17, 'y': 17, 'z': 17}
# 24: add x 14
# {'w': 1, 'x': 31, 'y': 17, 'z': 17}
# 25: eql x w
# {'w': 1, 'x': 0, 'y': 17, 'z': 17}
# 26: eql x 0
# {'w': 1, 'x': 1, 'y': 17, 'z': 17}
# 27: mul y 0
# {'w': 1, 'x': 1, 'y': 0, 'z': 17}
# 28: add y 25
# {'w': 1, 'x': 1, 'y': 25, 'z': 17}
# 29: mul y x
# {'w': 1, 'x': 1, 'y': 25, 'z': 17}
# 30: add y 1
# {'w': 1, 'x': 1, 'y': 26, 'z': 17}
# 31: mul z y
# {'w': 1, 'x': 1, 'y': 26, 'z': 442}
# 32: mul y 0
# {'w': 1, 'x': 1, 'y': 0, 'z': 442}
# 33: add y w
# {'w': 1, 'x': 1, 'y': 1, 'z': 442}
# 34: add y 12
# {'w': 1, 'x': 1, 'y': 13, 'z': 442}
# 35: mul y x
# {'w': 1, 'x': 1, 'y': 13, 'z': 442}
# 36: add z y
# {'w': 1, 'x': 1, 'y': 13, 'z': 455}
# 37: inp w
# {'w': 1, 'x': 1, 'y': 13, 'z': 455}
# 38: mul x 0
# {'w': 1, 'x': 0, 'y': 13, 'z': 455}
# 39: add x z
# {'w': 1, 'x': 455, 'y': 13, 'z': 455}
# 40: mod x 26
# {'w': 1, 'x': 13, 'y': 13, 'z': 455}
# 41: div z 1
# {'w': 1, 'x': 13, 'y': 13, 'z': 455}
# 42: add x 11
# {'w': 1, 'x': 24, 'y': 13, 'z': 455}
# 43: eql x w
# {'w': 1, 'x': 0, 'y': 13, 'z': 455}
# 44: eql x 0
# {'w': 1, 'x': 1, 'y': 13, 'z': 455}
# 45: mul y 0
# {'w': 1, 'x': 1, 'y': 0, 'z': 455}
# 46: add y 25
# {'w': 1, 'x': 1, 'y': 25, 'z': 455}
# 47: mul y x
# {'w': 1, 'x': 1, 'y': 25, 'z': 455}
# 48: add y 1
# {'w': 1, 'x': 1, 'y': 26, 'z': 455}
# 49: mul z y
# {'w': 1, 'x': 1, 'y': 26, 'z': 11830}
# 50: mul y 0
# {'w': 1, 'x': 1, 'y': 0, 'z': 11830}
# 51: add y w
# {'w': 1, 'x': 1, 'y': 1, 'z': 11830}
# 52: add y 15
# {'w': 1, 'x': 1, 'y': 16, 'z': 11830}
# 53: mul y x
# {'w': 1, 'x': 1, 'y': 16, 'z': 11830}
# 54: add z y
# {'w': 1, 'x': 1, 'y': 16, 'z': 11846}
# 55: inp w
# {'w': 7, 'x': 1, 'y': 16, 'z': 11846}
# 56: mul x 0
# {'w': 7, 'x': 0, 'y': 16, 'z': 11846}
# 57: add x z
# {'w': 7, 'x': 11846, 'y': 16, 'z': 11846}
# 58: mod x 26
# {'w': 7, 'x': 16, 'y': 16, 'z': 11846}
# 59: div z 26
# {'w': 7, 'x': 16, 'y': 16, 'z': 455}
# 60: add x -9
# {'w': 7, 'x': 7, 'y': 16, 'z': 455}
# 61: eql x w
# {'w': 7, 'x': 1, 'y': 16, 'z': 455}
# 62: eql x 0
# {'w': 7, 'x': 0, 'y': 16, 'z': 455}
# 63: mul y 0
# {'w': 7, 'x': 0, 'y': 0, 'z': 455}
# 64: add y 25
# {'w': 7, 'x': 0, 'y': 25, 'z': 455}
# 65: mul y x
# {'w': 7, 'x': 0, 'y': 0, 'z': 455}
# 66: add y 1
# {'w': 7, 'x': 0, 'y': 1, 'z': 455}
# 67: mul z y
# {'w': 7, 'x': 0, 'y': 1, 'z': 455}
# 68: mul y 0
# {'w': 7, 'x': 0, 'y': 0, 'z': 455}
# 69: add y w
# {'w': 7, 'x': 0, 'y': 7, 'z': 455}
# 70: add y 12
# {'w': 7, 'x': 0, 'y': 19, 'z': 455}
# 71: mul y x
# {'w': 7, 'x': 0, 'y': 0, 'z': 455}
# 72: add z y
# {'w': 7, 'x': 0, 'y': 0, 'z': 455}
# 73: inp w
# {'w': 6, 'x': 0, 'y': 0, 'z': 455}
# 74: mul x 0
# {'w': 6, 'x': 0, 'y': 0, 'z': 455}
# 75: add x z
# {'w': 6, 'x': 455, 'y': 0, 'z': 455}
# 76: mod x 26
# {'w': 6, 'x': 13, 'y': 0, 'z': 455}
# 77: div z 26
# {'w': 6, 'x': 13, 'y': 0, 'z': 17}
# 78: add x -7
# {'w': 6, 'x': 6, 'y': 0, 'z': 17}
# 79: eql x w
# {'w': 6, 'x': 1, 'y': 0, 'z': 17}
# 80: eql x 0
# {'w': 6, 'x': 0, 'y': 0, 'z': 17}
# 81: mul y 0
# {'w': 6, 'x': 0, 'y': 0, 'z': 17}
# 82: add y 25
# {'w': 6, 'x': 0, 'y': 25, 'z': 17}
# 83: mul y x
# {'w': 6, 'x': 0, 'y': 0, 'z': 17}
# 84: add y 1
# {'w': 6, 'x': 0, 'y': 1, 'z': 17}
# 85: mul z y
# {'w': 6, 'x': 0, 'y': 1, 'z': 17}
# 86: mul y 0
# {'w': 6, 'x': 0, 'y': 0, 'z': 17}
# 87: add y w
# {'w': 6, 'x': 0, 'y': 6, 'z': 17}
# 88: add y 15
# {'w': 6, 'x': 0, 'y': 21, 'z': 17}
# 89: mul y x
# {'w': 6, 'x': 0, 'y': 0, 'z': 17}
# 90: add z y
# {'w': 6, 'x': 0, 'y': 0, 'z': 17}
# 91: inp w
# {'w': 1, 'x': 0, 'y': 0, 'z': 17}
# 92: mul x 0
# {'w': 1, 'x': 0, 'y': 0, 'z': 17}
# 93: add x z
# {'w': 1, 'x': 17, 'y': 0, 'z': 17}
# 94: mod x 26
# {'w': 1, 'x': 17, 'y': 0, 'z': 17}
# 95: div z 1
# {'w': 1, 'x': 17, 'y': 0, 'z': 17}
# 96: add x 11
# {'w': 1, 'x': 28, 'y': 0, 'z': 17}
# 97: eql x w
# {'w': 1, 'x': 0, 'y': 0, 'z': 17}
# 98: eql x 0
# {'w': 1, 'x': 1, 'y': 0, 'z': 17}
# 99: mul y 0
# {'w': 1, 'x': 1, 'y': 0, 'z': 17}
# 100: add y 25
# {'w': 1, 'x': 1, 'y': 25, 'z': 17}
# 101: mul y x
# {'w': 1, 'x': 1, 'y': 25, 'z': 17}
# 102: add y 1
# {'w': 1, 'x': 1, 'y': 26, 'z': 17}
# 103: mul z y
# {'w': 1, 'x': 1, 'y': 26, 'z': 442}
# 104: mul y 0
# {'w': 1, 'x': 1, 'y': 0, 'z': 442}
# 105: add y w
# {'w': 1, 'x': 1, 'y': 1, 'z': 442}
# 106: add y 2
# {'w': 1, 'x': 1, 'y': 3, 'z': 442}
# 107: mul y x
# {'w': 1, 'x': 1, 'y': 3, 'z': 442}
# 108: add z y
# {'w': 1, 'x': 1, 'y': 3, 'z': 445}
# 109: inp w
# {'w': 2, 'x': 1, 'y': 3, 'z': 445}
# 110: mul x 0
# {'w': 2, 'x': 0, 'y': 3, 'z': 445}
# 111: add x z
# {'w': 2, 'x': 445, 'y': 3, 'z': 445}
# 112: mod x 26
# {'w': 2, 'x': 3, 'y': 3, 'z': 445}
# 113: div z 26
# {'w': 2, 'x': 3, 'y': 3, 'z': 17}
# 114: add x -1
# {'w': 2, 'x': 2, 'y': 3, 'z': 17}
# 115: eql x w
# {'w': 2, 'x': 1, 'y': 3, 'z': 17}
# 116: eql x 0
# {'w': 2, 'x': 0, 'y': 3, 'z': 17}
# 117: mul y 0
# {'w': 2, 'x': 0, 'y': 0, 'z': 17}
# 118: add y 25
# {'w': 2, 'x': 0, 'y': 25, 'z': 17}
# 119: mul y x
# {'w': 2, 'x': 0, 'y': 0, 'z': 17}
# 120: add y 1
# {'w': 2, 'x': 0, 'y': 1, 'z': 17}
# 121: mul z y
# {'w': 2, 'x': 0, 'y': 1, 'z': 17}
# 122: mul y 0
# {'w': 2, 'x': 0, 'y': 0, 'z': 17}
# 123: add y w
# {'w': 2, 'x': 0, 'y': 2, 'z': 17}
# 124: add y 11
# {'w': 2, 'x': 0, 'y': 13, 'z': 17}
# 125: mul y x
# {'w': 2, 'x': 0, 'y': 0, 'z': 17}
# 126: add z y
# {'w': 2, 'x': 0, 'y': 0, 'z': 17}
# 127: inp w
# {'w': 1, 'x': 0, 'y': 0, 'z': 17}
# 128: mul x 0
# {'w': 1, 'x': 0, 'y': 0, 'z': 17}
# 129: add x z
# {'w': 1, 'x': 17, 'y': 0, 'z': 17}
# 130: mod x 26
# {'w': 1, 'x': 17, 'y': 0, 'z': 17}
# 131: div z 26
# {'w': 1, 'x': 17, 'y': 0, 'z': 0}
# 132: add x -16
# {'w': 1, 'x': 1, 'y': 0, 'z': 0}
# 133: eql x w
# {'w': 1, 'x': 1, 'y': 0, 'z': 0}
# 134: eql x 0
# {'w': 1, 'x': 0, 'y': 0, 'z': 0}
# 135: mul y 0
# {'w': 1, 'x': 0, 'y': 0, 'z': 0}
# 136: add y 25
# {'w': 1, 'x': 0, 'y': 25, 'z': 0}
# 137: mul y x
# {'w': 1, 'x': 0, 'y': 0, 'z': 0}
# 138: add y 1
# {'w': 1, 'x': 0, 'y': 1, 'z': 0}
# 139: mul z y
# {'w': 1, 'x': 0, 'y': 1, 'z': 0}
# 140: mul y 0
# {'w': 1, 'x': 0, 'y': 0, 'z': 0}
# 141: add y w
# {'w': 1, 'x': 0, 'y': 1, 'z': 0}
# 142: add y 15
# {'w': 1, 'x': 0, 'y': 16, 'z': 0}
# 143: mul y x
# {'w': 1, 'x': 0, 'y': 0, 'z': 0}
# 144: add z y
# {'w': 1, 'x': 0, 'y': 0, 'z': 0}
# 145: inp w
# {'w': 6, 'x': 0, 'y': 0, 'z': 0}
# 146: mul x 0
# {'w': 6, 'x': 0, 'y': 0, 'z': 0}
# 147: add x z
# {'w': 6, 'x': 0, 'y': 0, 'z': 0}
# 148: mod x 26
# {'w': 6, 'x': 0, 'y': 0, 'z': 0}
# 149: div z 1
# {'w': 6, 'x': 0, 'y': 0, 'z': 0}
# 150: add x 11
# {'w': 6, 'x': 11, 'y': 0, 'z': 0}
# 151: eql x w
# {'w': 6, 'x': 0, 'y': 0, 'z': 0}
# 152: eql x 0
# {'w': 6, 'x': 1, 'y': 0, 'z': 0}
# 153: mul y 0
# {'w': 6, 'x': 1, 'y': 0, 'z': 0}
# 154: add y 25
# {'w': 6, 'x': 1, 'y': 25, 'z': 0}
# 155: mul y x
# {'w': 6, 'x': 1, 'y': 25, 'z': 0}
# 156: add y 1
# {'w': 6, 'x': 1, 'y': 26, 'z': 0}
# 157: mul z y
# {'w': 6, 'x': 1, 'y': 26, 'z': 0}
# 158: mul y 0
# {'w': 6, 'x': 1, 'y': 0, 'z': 0}
# 159: add y w
# {'w': 6, 'x': 1, 'y': 6, 'z': 0}
# 160: add y 10
# {'w': 6, 'x': 1, 'y': 16, 'z': 0}
# 161: mul y x
# {'w': 6, 'x': 1, 'y': 16, 'z': 0}
# 162: add z y
# {'w': 6, 'x': 1, 'y': 16, 'z': 16}
# 163: inp w
# {'w': 1, 'x': 1, 'y': 16, 'z': 16}
# 164: mul x 0
# {'w': 1, 'x': 0, 'y': 16, 'z': 16}
# 165: add x z
# {'w': 1, 'x': 16, 'y': 16, 'z': 16}
# 166: mod x 26
# {'w': 1, 'x': 16, 'y': 16, 'z': 16}
# 167: div z 26
# {'w': 1, 'x': 16, 'y': 16, 'z': 0}
# 168: add x -15
# {'w': 1, 'x': 1, 'y': 16, 'z': 0}
# 169: eql x w
# {'w': 1, 'x': 1, 'y': 16, 'z': 0}
# 170: eql x 0
# {'w': 1, 'x': 0, 'y': 16, 'z': 0}
# 171: mul y 0
# {'w': 1, 'x': 0, 'y': 0, 'z': 0}
# 172: add y 25
# {'w': 1, 'x': 0, 'y': 25, 'z': 0}
# 173: mul y x
# {'w': 1, 'x': 0, 'y': 0, 'z': 0}
# 174: add y 1
# {'w': 1, 'x': 0, 'y': 1, 'z': 0}
# 175: mul z y
# {'w': 1, 'x': 0, 'y': 1, 'z': 0}
# 176: mul y 0
# {'w': 1, 'x': 0, 'y': 0, 'z': 0}
# 177: add y w
# {'w': 1, 'x': 0, 'y': 1, 'z': 0}
# 178: add y 2
# {'w': 1, 'x': 0, 'y': 3, 'z': 0}
# 179: mul y x
# {'w': 1, 'x': 0, 'y': 0, 'z': 0}
# 180: add z y
# {'w': 1, 'x': 0, 'y': 0, 'z': 0}
# 181: inp w
# {'w': 1, 'x': 0, 'y': 0, 'z': 0}
# 182: mul x 0
# {'w': 1, 'x': 0, 'y': 0, 'z': 0}
# 183: add x z
# {'w': 1, 'x': 0, 'y': 0, 'z': 0}
# 184: mod x 26
# {'w': 1, 'x': 0, 'y': 0, 'z': 0}
# 185: div z 1
# {'w': 1, 'x': 0, 'y': 0, 'z': 0}
# 186: add x 10
# {'w': 1, 'x': 10, 'y': 0, 'z': 0}
# 187: eql x w
# {'w': 1, 'x': 0, 'y': 0, 'z': 0}
# 188: eql x 0
# {'w': 1, 'x': 1, 'y': 0, 'z': 0}
# 189: mul y 0
# {'w': 1, 'x': 1, 'y': 0, 'z': 0}
# 190: add y 25
# {'w': 1, 'x': 1, 'y': 25, 'z': 0}
# 191: mul y x
# {'w': 1, 'x': 1, 'y': 25, 'z': 0}
# 192: add y 1
# {'w': 1, 'x': 1, 'y': 26, 'z': 0}
# 193: mul z y
# {'w': 1, 'x': 1, 'y': 26, 'z': 0}
# 194: mul y 0
# {'w': 1, 'x': 1, 'y': 0, 'z': 0}
# 195: add y w
# {'w': 1, 'x': 1, 'y': 1, 'z': 0}
# 196: add y 0
# {'w': 1, 'x': 1, 'y': 1, 'z': 0}
# 197: mul y x
# {'w': 1, 'x': 1, 'y': 1, 'z': 0}
# 198: add z y
# {'w': 1, 'x': 1, 'y': 1, 'z': 1}
# 199: inp w
# {'w': 5, 'x': 1, 'y': 1, 'z': 1}
# 200: mul x 0
# {'w': 5, 'x': 0, 'y': 1, 'z': 1}
# 201: add x z
# {'w': 5, 'x': 1, 'y': 1, 'z': 1}
# 202: mod x 26
# {'w': 5, 'x': 1, 'y': 1, 'z': 1}
# 203: div z 1
# {'w': 5, 'x': 1, 'y': 1, 'z': 1}
# 204: add x 12
# {'w': 5, 'x': 13, 'y': 1, 'z': 1}
# 205: eql x w
# {'w': 5, 'x': 0, 'y': 1, 'z': 1}
# 206: eql x 0
# {'w': 5, 'x': 1, 'y': 1, 'z': 1}
# 207: mul y 0
# {'w': 5, 'x': 1, 'y': 0, 'z': 1}
# 208: add y 25
# {'w': 5, 'x': 1, 'y': 25, 'z': 1}
# 209: mul y x
# {'w': 5, 'x': 1, 'y': 25, 'z': 1}
# 210: add y 1
# {'w': 5, 'x': 1, 'y': 26, 'z': 1}
# 211: mul z y
# {'w': 5, 'x': 1, 'y': 26, 'z': 26}
# 212: mul y 0
# {'w': 5, 'x': 1, 'y': 0, 'z': 26}
# 213: add y w
# {'w': 5, 'x': 1, 'y': 5, 'z': 26}
# 214: add y 0
# {'w': 5, 'x': 1, 'y': 5, 'z': 26}
# 215: mul y x
# {'w': 5, 'x': 1, 'y': 5, 'z': 26}
# 216: add z y
# {'w': 5, 'x': 1, 'y': 5, 'z': 31}
# 217: inp w
# {'w': 1, 'x': 1, 'y': 5, 'z': 31}
# 218: mul x 0
# {'w': 1, 'x': 0, 'y': 5, 'z': 31}
# 219: add x z
# {'w': 1, 'x': 31, 'y': 5, 'z': 31}
# 220: mod x 26
# {'w': 1, 'x': 5, 'y': 5, 'z': 31}
# 221: div z 26
# {'w': 1, 'x': 5, 'y': 5, 'z': 1}
# 222: add x -4
# {'w': 1, 'x': 1, 'y': 5, 'z': 1}
# 223: eql x w
# {'w': 1, 'x': 1, 'y': 5, 'z': 1}
# 224: eql x 0
# {'w': 1, 'x': 0, 'y': 5, 'z': 1}
# 225: mul y 0
# {'w': 1, 'x': 0, 'y': 0, 'z': 1}
# 226: add y 25
# {'w': 1, 'x': 0, 'y': 25, 'z': 1}
# 227: mul y x
# {'w': 1, 'x': 0, 'y': 0, 'z': 1}
# 228: add y 1
# {'w': 1, 'x': 0, 'y': 1, 'z': 1}
# 229: mul z y
# {'w': 1, 'x': 0, 'y': 1, 'z': 1}
# 230: mul y 0
# {'w': 1, 'x': 0, 'y': 0, 'z': 1}
# 231: add y w
# {'w': 1, 'x': 0, 'y': 1, 'z': 1}
# 232: add y 15
# {'w': 1, 'x': 0, 'y': 16, 'z': 1}
# 233: mul y x
# {'w': 1, 'x': 0, 'y': 0, 'z': 1}
# 234: add z y
# {'w': 1, 'x': 0, 'y': 0, 'z': 1}
# 235: inp w
# {'w': 1, 'x': 0, 'y': 0, 'z': 1}
# 236: mul x 0
# {'w': 1, 'x': 0, 'y': 0, 'z': 1}
# 237: add x z
# {'w': 1, 'x': 1, 'y': 0, 'z': 1}
# 238: mod x 26
# {'w': 1, 'x': 1, 'y': 0, 'z': 1}
# 239: div z 26
# {'w': 1, 'x': 1, 'y': 0, 'z': 0}
# 240: add x 0
# {'w': 1, 'x': 1, 'y': 0, 'z': 0}
# 241: eql x w
# {'w': 1, 'x': 1, 'y': 0, 'z': 0}
# 242: eql x 0
# {'w': 1, 'x': 0, 'y': 0, 'z': 0}
# 243: mul y 0
# {'w': 1, 'x': 0, 'y': 0, 'z': 0}
# 244: add y 25
# {'w': 1, 'x': 0, 'y': 25, 'z': 0}
# 245: mul y x
# {'w': 1, 'x': 0, 'y': 0, 'z': 0}
# 246: add y 1
# {'w': 1, 'x': 0, 'y': 1, 'z': 0}
# 247: mul z y
# {'w': 1, 'x': 0, 'y': 1, 'z': 0}
# 248: mul y 0
# {'w': 1, 'x': 0, 'y': 0, 'z': 0}
# 249: add y w
# {'w': 1, 'x': 0, 'y': 1, 'z': 0}
# 250: add y 15
# {'w': 1, 'x': 0, 'y': 16, 'z': 0}
# 251: mul y x
# {'w': 1, 'x': 0, 'y': 0, 'z': 0}
# 252: add z y
# {'w': 1, 'x': 0, 'y': 0, 'z': 0}

# %%
regs['z']
# Out:
# 0
